# %%
import time
import random
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import pandas as pd
from datetime import datetime
import math 

from sql_functions import *    

import psycopg2   

import sql_functions as sf
from sql_functions import get_dataframe
import sqlalchemy

# %% [markdown]
# ## Get all details

# %%
# get list of platform_ids from DBeaver first

schema = 'capstone_jmrs'

sql = f"""
SELECT platform_id 
FROM {schema}.rightmove_3
"""

df = get_dataframe(sql)

#------------------------------------------------------------
#------------------------------------------------------------


#ids = df['platform_id'].tolist()

#ids = ['127325693', '127366049', '117388061', '127365830'] #for testing purposes only
#df_details_complete = pd.DataFrame()
#df_basics_complete = pd.DataFrame()

for id in ids[117:]:
    time.sleep(random.randint(2,5)/10)
    
    page = requests.get(f"https://www.rightmove.co.uk/properties/{id}#/?channel=RES_LET")
    html = page.content
    bs = BeautifulSoup(html, 'html.parser')

    bedrooms, bathrooms, size, property_type = 'NA', 'NA', 'NA', 'NA' 
    row_dict = {'property_id':id, 'bedrooms': bedrooms, 'bathrooms': bathrooms, 'size_sqm': size, 'property_type': property_type}
    # get details
    details = bs.find(
        'div', class_='_4hBezflLdgDMdFtURKTWh')
    if details == None:
        continue
    details_lst = (detail.get_text() for detail in details)
    details_lst = [detail.strip() for detail in details_lst]

    #df_details_complete = pd.DataFrame()
    # bedrooms, bathrooms, size, property_type = 'NA', 'NA', 'NA', 'NA' 
    # row_dict = {'property_id':id, 'bedrooms': bedrooms, 'bathrooms': bathrooms, 'size': size, 'property_type': property_type}
    for detail in details_lst:
        if 'TYPE' in detail:
            row_dict['property_type'] = detail.removeprefix('PROPERTY TYPE')
        elif 'BEDROOMS' in detail:
            row_dict['bedrooms'] = detail[-1]
        elif 'BATHROOM' in detail:
            row_dict['bathrooms'] = detail[-1]
        elif 'SIZE' in detail:
            row_dict['size'] = re.search(r'\((.*?)\)', str(detail)).group(1).removesuffix(' sq. m.').replace(',', '').split('-')[0] #grabs lower number, if size is given as a range ################## NON MVP APPROACH tbd?
    
    # store
    df_details = pd.DataFrame(row_dict, index=[0])    
    df_details_complete = pd.concat([df_details_complete, df_details], ignore_index=True)

    # get other basic details
    basics = bs.find_all(
        'div', class_='_2RnXSVJcWbWv4IpBC1Sng6')

    basics_lst = (basic.get_text() for basic in basics)
    basics_lst = [basic.strip().split(': ') for basic in basics_lst]    #'split'
    basics_lst

    # convert details_lst to dict
    itemDict = {item[0]: item[1] for item in basics_lst}
    itemDict['platform_id'] = id

    df_basics = pd.DataFrame(itemDict, index=[0])    
    df_basics_complete = pd.concat([df_basics_complete, df_basics], ignore_index=True)


# drop basics columns we don't need
df_basics_complete.drop(['Deposit', 'Min. Tenancy', 'Council Tax'], axis=1, inplace=True)

# pythonise column names 
df_basics_complete.columns.values[0:3] = ['available_from', 'let_type', 'furnished']

# concatenate both detail DFs
new_df = pd.concat([df_details_complete, df_basics_complete], axis=1)

# drop duplicates
new_df.drop_duplicates(inplace=True)



# import the data frame to DBeaver
# call the schema created for this project
schema = 'capstone_jmrs'
# get the function to connect to the database
engine = get_engine()

# give the table a unique name
table_name = 'rightmove_details_orig'

# import the table to sql
if engine!=None:
    try:
        new_df.to_sql(name=table_name,
                        con=engine,
                        if_exists='replace',
                        schema=schema, 
                        index=False,
                        chunksize=5000, 
                        method='multi')
        print(f"The {table_name} table was imported successfully.")
    
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        engine = None

# first run took approx 124minutes
# Out:
# The rightmove_details table was imported successfully.

# %%
df_details_complete.tail(20)
# Out:
#     property_id bedrooms bathrooms size property_type
# 113   127177253        4         2   NA      Terraced
# 114   127169546        1         1   NA     Apartment
# 115   116919512        3        NA   NA     Apartment
# 116   126997865        1        NA   NA     Apartment
# 117   127168676        2         1   62          Flat
# 118    76519706        2         2   66     Apartment
# 119   100658471        1         1   45     Apartment
# 120   127162790        2         1   NA     Apartment
# 121   126767408        1         1   NA          Flat
# 122   127151582        2         1   NA          Flat
# 123    85488675        3         3   NA          Flat
# 124   127146941        2         2   NA          Flat
# 125   127141016        2         2   NA          Flat
# 126   127140656        2         1   NA     Apartment
# 127   127140446        2         2   NA     Apartment
# 128   127140260        3         3   NA     Apartment
# 129   127134104        2         2   NA          Flat
# 130   127122653        2         1   NA          Flat
# 131   127122332        1         1   NA          Flat
# 132   127115051        1         1   NA          Flat

# %%
df_details_complete.corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#### Important Info: class "_1_ReydbZyb288nsZPkRSw_" only occurs if website is found, but property has already been removed (e.g. 127092152)
# 117 118069259 (completely removed, website available, but without detail information)
# 127 126889337
# 135 127115051

    # get details
eins_df = pd.DataFrame()
zwei_df = pd.DataFrame()

page = requests.get(f"https://www.rightmove.co.uk/properties/127092152#/?channel=RES_LET")
html = page.content
bs = BeautifulSoup(html, 'html.parser')
details = bs.find(
    'div', class_='_4hBezflLdgDMdFtURKTWh')
if details == None:
    continue       
details_lst = (detail.get_text() for detail in details)
details_lst = [detail.strip() for detail in details_lst]

#df_details_complete = pd.DataFrame()
bedrooms, bathrooms, size, property_type = 'NA', 'NA', 'NA', 'NA' 
row_dict = {'property_id':id, 'bedrooms': bedrooms, 'bathrooms': bathrooms, 'size': size, 'property_type': property_type}
for detail in details_lst:
    if 'TYPE' in detail:
        row_dict['property_type'] = detail.removeprefix('PROPERTY TYPE')
    elif 'BEDROOMS' in detail:
        row_dict['bedrooms'] = detail[-1]
    elif 'BATHROOM' in detail:
        row_dict['bathrooms'] = detail[-1]
    elif 'SIZE' in detail:
        row_dict['size_sqm'] = re.search(r'\((.*?)\)', str(detail)).group(1).removesuffix(' sq. m.').replace(',', '')

eins_df = pd.DataFrame(row_dict, index=[0])    
zwei_df = pd.concat([zwei_df, eins_df], ignore_index=True)
# Out:
#   Input In [37]
#     continue
#     ^
# SyntaxError: 'continue' not properly in loop

# %%
prop vs platf id ?!

# %%
new_df.drop(['Council Tax'], axis=1, inplace=True)

# %%
new_df['property_id'].nunique()
# Out:
# 6602

# %%
for i in range(len(ids[118:])):
    if i > 110:
        print(i, ids[i])

# %% [markdown]
# ### end of working code

# %%
# # doesnt take too long
# itemDict = {item[0]: item[1] for item in basics_lst}
# itemDict['property_id'] = id

# itemDict

# %%
# SIZE from detail page - Works, but what if there is no size?

sizes = bs_2.find(
    'p', class_='_3vyydJK3KMwn7-s2BEXJAf')

sizes_lst = (detail.get_text() for detail in sizes)
sizes_lst = [detail.strip() for detail in sizes_lst]

# convert string
# df['size'] = df['size'].str.removesuffix('sq. m.)').str.replace('(', '').str.replace(',', '')
sizes_lst
# Out:
# ['(32 sq. m.)']

# %%
details = bs_2.find(
    'div', class_='_4hBezflLdgDMdFtURKTWh')
details_lst = (detail.get_text() for detail in details)
details_lst = [detail.strip() for detail in details_lst]
details_lst
# Out:
# ['PROPERTY TYPEApartment', 'BATHROOMS×1']

# %%
## Would work, but breaks as soon as there is no size (maybe convert to dictionary first?)
page_2 = requests.get("https://www.rightmove.co.uk/properties/127325693#/?channel=RES_LET")
html_2 = page_2.content
bs_2 = BeautifulSoup(html_2, 'html.parser')


# TYPE  -- BEDROOMS -- BATHROOMS -- SIZE
details = bs_2.find(
    'div', class_='_4hBezflLdgDMdFtURKTWh')
details_lst = (detail.get_text() for detail in details)
details_lst = [detail.strip() for detail in details_lst]
details_lst

# Format entries
# details_lst[0] = str(details_lst[0]).replace('PROPERTY TYPE', '')
# details_lst[1] = str(details_lst[1]).replace('BEDROOMS×', '')
# details_lst[2] = str(details_lst[2]).replace('BATHROOMS×', '')
# #details_lst[3] = re.search(r'\((.*?)\)', str(details_lst[3])).group(1).removesuffix(' sq. m.').replace(',', '')

details_lst
# Out:
# ['PROPERTY TYPEApartment', 'BATHROOMS×1']

# %% [markdown]
# ## OVERVIEW PAGE

# %%
# BEEDROOMS - WORKS!
bedrooms = [title.text.split('bedroom')[0].strip() for title in bs.findAll('h2', {'class': 'propertyCard-title'})]
bedrooms

# %%
# TYPE - Working so far!
types_lst = [title.text.strip().split()[-1] for title in bs.findAll('h2', {'class': 'propertyCard-title'})]
types_lst

# %%
# BATHROOMS NOT WORKING AT ALL

bathrooms = bs.find_all(class_= "propertyCard-features")
bathrooms_lst = [bathroom.get_text() for bathroom in bathrooms]
bathrooms_lst = list(filter(None, bathrooms_lst)) #delete any empty strings from list
bathrooms_lst
# # format bathrooms
# bathrooms_lst = [bathroom.split('bathroom')[0].strip() for bathroom in bathrooms_lst]
# bathrooms_lst
# Out:
# []

# %%
# Date added or reduced
dates_edited = [date.text for date in bs.findAll('span', {'class': 'propertyCard-branchSummary-addedOrReduced'})]
dates_edited

## possibly chec/update price in DB if value='reduced...'
# Out:
# []

# %% [markdown]
# ## Detail Code from Julia

# %%
from sql_functions import get_dataframe

# %%
schema = 'capstone_jmrs'

# %%
sql = f"""
SELECT * 
FROM {schema}.rightmove_clean
"""

df_clean = get_dataframe(sql)
df_clean
# Out:
#      platform_id   platform           neighbourhood    furniture  \
# 0      127237268  Rightmove  Hammersmith and Fulham    furnished
# 1      123512255  Rightmove  Kensington and Chelsea    furnished
# 2      126331931  Rightmove  Kensington and Chelsea    furnished
# 3      126286028  Rightmove  Kensington and Chelsea    furnished
# 4      126315152  Rightmove  Kensington and Chelsea    furnished
# ...          ...        ...                     ...          ...
# 6568   126625880  Rightmove           Tower Hamlets  unfurnished
# 6569   126601460  Rightmove           Tower Hamlets  unfurnished
# 6570   126575720  Rightmove           Tower Hamlets  unfurnished
# 6571   126546053  Rightmove           Tower Hamlets  unfurnished
# 6572   126377570  Rightmove           Tower Hamlets  unfurnished
#
#      property_type  size_sqm  bedrooms  bathrooms  price_pcm  price_per_sqm  \
# 0             Flat       NaN       2.0        2.0     4008.0            NaN
# 1       Maisonette       NaN       3.0        3.0     6912.0            NaN
# 2             Flat       NaN       1.0        1.0     4117.0            NaN
# 3            House     206.0       4.0        4.0    10833.0          52.59
# 4        Apartment      35.0       NaN        1.0     1733.0          49.51
# ...            ...       ...       ...        ...        ...            ...
# 6568          Flat       NaN       1.0        1.0     2197.0            NaN
# 6569          Flat     289.0       4.0        4.0    10833.0          37.48
# 6570          Flat      34.0       1.0        1.0     1625.0          47.79
# 6571          Flat      52.0       1.0        1.0     2200.0          42.31
# 6572          Flat      43.0       1.0        1.0     1700.0          39.53
#
#       price_per_bedroom available_from available_today   let_type  \
# 0               2004.00     2022-09-23       available  Long term
# 1               2304.00     2022-09-23       available  Long term
# 2               4117.00     2022-09-23       available  Long term
# 3               2708.25     2022-09-23       available  Long term
# 4                   NaN     2022-10-19        occupied  Long term
# ...                 ...            ...             ...        ...
# 6568            2197.00           None         unclear  Long term
# 6569            2708.25           None         unclear  Long term
# 6570            1625.00           None         unclear  Long term
# 6571            2200.00           None         unclear  Long term
# 6572            1700.00           None         unclear  Long term
#
#      scraping_date
# 0       2022-09-23
# 1       2022-09-23
# 2       2022-09-23
# 3       2022-09-23
# 4       2022-09-23
# ...            ...
# 6568    2022-09-23
# 6569    2022-09-23
# 6570    2022-09-23
# 6571    2022-09-23
# 6572    2022-09-23
#
# [6573 rows x 15 columns]

# %%
df_clean.head(3)
# Out:
#   platform_id   platform           neighbourhood  furniture property_type  \
# 0   127237268  Rightmove  Hammersmith and Fulham  furnished          Flat
# 1   123512255  Rightmove  Kensington and Chelsea  furnished    Maisonette
# 2   126331931  Rightmove  Kensington and Chelsea  furnished          Flat
#
#    size_sqm  bedrooms  bathrooms  price_pcm  price_per_sqm  price_per_bedroom  \
# 0       NaN       2.0        2.0     4008.0            NaN             2004.0
# 1       NaN       3.0        3.0     6912.0            NaN             2304.0
# 2       NaN       1.0        1.0     4117.0            NaN             4117.0
#
#   available_from available_today   let_type scraping_date
# 0     2022-09-23       available  Long term    2022-09-23
# 1     2022-09-23       available  Long term    2022-09-23
# 2     2022-09-23       available  Long term    2022-09-23

# %%
df_clean.describe()
# Out:
#           size_sqm     bedrooms    bathrooms      price_pcm  price_per_sqm  \
# count  1605.000000  6441.000000  6261.000000    6573.000000    1605.000000
# mean     99.952648     2.241577     1.858808    6240.377149      66.240854
# std     100.003954     1.211751     0.952983    9622.049428      90.424064
# min       3.000000     0.000000     0.000000     195.000000       4.380000
# 25%      53.000000     1.000000     1.000000    2687.000000      40.440000
# 50%      78.000000     2.000000     2.000000    4000.000000      52.000000
# 75%     109.000000     3.000000     2.000000    6478.000000      68.490000
# max    2224.000000    10.000000     8.000000  346667.000000    1665.000000
#
#        price_per_bedroom
# count        6441.000000
# mean         2677.706322
# std          2648.802573
# min           475.000000
# 25%          1582.000000
# 50%          2058.500000
# 75%          2925.000000
# max         65000.000000

# %%
df_clean.query("furniture == 'furnished'").describe()
# Out:
#           size_sqm     bedrooms    bathrooms      price_pcm  price_per_sqm  \
# count  1068.000000  4681.000000  4548.000000    4787.000000    1068.000000
# mean     98.629213     2.135228     1.829815    6581.196574      74.990721
# std     108.677701     1.180269     0.946127   10718.241406     106.911427
# min       3.000000     0.000000     0.000000     195.000000       4.380000
# 25%      52.000000     1.000000     1.000000    2800.000000      46.150000
# 50%      76.000000     2.000000     2.000000    4117.000000      58.675000
# 75%     104.250000     3.000000     2.000000    6305.000000      75.020000
# max    2224.000000    10.000000     8.000000  346667.000000    1665.000000
#
#        price_per_bedroom
# count        4681.000000
# mean         2905.405223
# std          2834.389160
# min           475.000000
# 25%          1712.000000
# 50%          2200.000000
# 75%          3087.500000
# max         65000.000000

# %%
# df_clean.query("furniture == 'furnished'")[['price_pcm', 'price_per_bedroom', 'price_per_sqm']].quantile(0.5)
df_clean[['price_pcm', 'price_per_bedroom', 'price_per_sqm']].quantile(0.5)
# Out:
# price_pcm            4000.0
# price_per_bedroom    2058.5
# price_per_sqm          52.0
# Name: 0.5, dtype: float64

# %%
df_clean.query("furniture == 'unfurnished'")[['price_pcm', 'price_per_bedroom', 'price_per_sqm']].quantile(0.5)
# Out:
# price_pcm            3684.00
# price_per_bedroom    1750.00
# price_per_sqm          42.39
# Name: 0.5, dtype: float64

# %%
df_clean.query("furniture == 'furnished'")[['price_pcm', 'price_per_bedroom', 'price_per_sqm']].quantile(0.6)
# Out:
# price_pcm            4800.000
# price_per_bedroom    2500.000
# price_per_sqm          64.638
# Name: 0.6, dtype: float64

# %%
df_clean.query("furniture == 'furnished'")[['price_pcm', 'price_per_bedroom', 'price_per_sqm']].quantile(0.9)
# Out:
# price_pcm            11267.000
# price_per_bedroom     4766.500
# price_per_sqm          103.625
# Name: 0.9, dtype: float64

# %% [markdown]
# ### SQL in Python START
# we define price band within rightmove (furnished and unfurnished seperately)
#
# TOP 10% price_pcm and low 50% price pcm will be marked as "out of range"
#
# blueground and spotahome properties will be marked as "targeted price range" completely

# %%
# Import the get_engine function from our sql_functions.
from sql_functions import get_engine #adjust this as necessary to match your sql_functions.py connection methods

# Import get_dataframe from sql_functions.py
from sql_functions import get_dataframe
from sql_functions import get_data
# create a variable called engine using the get_engine function
engine = get_engine()
print(engine)
print(type(engine))
# Out:
# Engine(postgresql://user:***@host/database)
# <class 'sqlalchemy.engine.base.Engine'>

# %%
schema
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/ruben/neuefische_rp/capstone/capstone-ukio-rep/rightmove_ruben_3_details.ipynb Cell 34 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/ruben/neuefische_rp/capstone/capstone-ukio-rep/rightmove_ruben_3_details.ipynb#Y114sZmlsZQ%3D%3D?line=0'>1</a> schema
#
# NameError: name 'schema' is not defined

# %%
sql_text = f"""
UPDATE {schema}.blueground_df_main
SET  bedrooms = 1
WHERE bedrooms = '1 Bedroom' ;
""" 
# Take the SQL-Command and execute it
result = engine.execute(sql_text)

# %%
# SQL CODE for getting percentiles
sql_text_1 ="""
    SELECT
    percentile_cont(0.50) within group (order by price_pcm asc) as percentile_05  
    from capstone_jmrs.rightmove_clean;
"""
# Out:
#   Input In [96]
#     int(perc_05) = sql_text_1 ="""
#     ^
# SyntaxError: cannot assign to function call

# %%
perc_05
# Out:
# '\n    SELECT\n    percentile_cont(0.50) within group (order by price_pcm asc) as percentile_05  \n    from capstone_jmrs.rightmove_clean;\n'

# %%
limits = get_data("""SELECT
    percentile_cont(0.50) within group (order by price_pcm asc) as percentile_50,
    percentile_cont(0.90) within group (order by price_pcm asc) as percentile_90 
    from capstone_jmrs.rightmove_clean
    WHERE furniture = 'unfurnished';""")
limits
# Out:
# [(3684.0, 9750.0)]

# %%
# sqm UNfurnished
limits_sqm_unfurn = get_data("""SELECT
    percentile_cont(0.50) within group (order by price_per_sqm asc) as percentile_50,
    percentile_cont(0.90) within group (order by price_per_sqm) as percentile_90 
    from capstone_jmrs.rightmove_clean
    WHERE furniture = 'unfurnished';""")
limits_sqm_unfurn
# Out:
# [(42.39, 67.03800000000001)]

# %%
data[530][0]

# %%
data = get_data("""SELECT price_sqm FROM capstone_jmrs.platforms_complete_3 WHERE furniture = 'unfurnished' AND platform = 'Rightmove';""")
data
# Out:
# [(None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  ...]

# %%
# sqm UNfurnished other table
limits_sqm_unfurn = get_data("""SELECT
    percentile_cont(0.50) within group (order by price_sqm asc) as percentile_50,
    percentile_cont(0.90) within group (order by price_sqm) as percentile_90 
    from capstone_jmrs.platforms_complete_3
    WHERE furniture = 'furnished' AND platform = 'Rightmove';
    """)
limits_sqm_unfurn
# Out:
# [(58.675, 103.62500000000001)]

# %%
# targeted percentiles for different groups
perc_50 = limits_sqm_unfurn[0][0]
perc_90 = round(limits_sqm_unfurn[0][1], 2)
print(perc_50, perc_90)
# Out:
# 58.675 103.63

# %%
# price sqm band unfurnished
sql_text_4 = f"""
UPDATE {schema}.platforms_complete_3
SET price_sqm_band = 'targeted price range'                
WHERE price_sqm BETWEEN {perc_50} AND {perc_90}
AND furniture = 'furnished' AND platform = 'Rightmove';
"""
result = engine.execute(sql_text_4)

# %%
sql_text_4 = f"""
UPDATE {schema}.platforms_complete_3
SET price_sqm_band = 'targeted price range'                
WHERE platform != 'Rightmove';
"""
result = engine.execute(sql_text_4)

# %%
# sqm furnished
limits_sqm_furn = get_data("""SELECT
    percentile_cont(0.50) within group (order by price_per_sqm asc) as percentile_50,
    percentile_cont(0.90) within group (order by price_per_sqm) as percentile_90 
    from capstone_jmrs.rightmove_clean
    WHERE furniture = 'furnished';""")
limits_sqm_furn
# Out:
# [(58.675, 103.62500000000001)]

# %%
SELECT C

# %%
limits = get_data("""SELECT
    percentile_cont(0.50) within group (order by price_pcm asc) as percentile_50,
    percentile_cont(0.90) within group (order by price_pcm asc) as percentile_90 
    from capstone_jmrs.rightmove_clean
    WHERE furniture = 'furnished';""")
limits
# Out:
# [(4117.0, 11267.0)]

# %%
sql_text_1 = """
ALTER TABLE capstone_jmrs.rightmove_clean
ADD COLUMN percentile_view VARCHAR;
"""
result = engine.execute(sql_text_1)

# %%
schema = 'capstone_jmrs'

# %%
sql_text_2 = f"""
UPDATE {schema}.rightmove_clean
SET percentile_view = 'targeted price range'                # now: price_band
WHERE price_pcm BETWEEN {perc_50} AND {perc_90}
AND furniture = 'furnished';
"""
result = engine.execute(sql_text_2)

# %%
sql_text_3 = f"""
UPDATE {schema}.rightmove_clean
SET percentile_view = 'out of range'
WHERE price_pcm NOT BETWEEN {perc_50} AND {perc_90}
AND furniture = 'furnished';
"""
result = engine.execute(sql_text_3)

# %%
# Delete blueground_df_details table if it exists
# sql_text = f"""
# DROP TABLE IF EXISTS capstone_jmrs.blueground_df_details;
#     """ 
# Take the SQL-Command and execute it
result = engine.execute(sql_text_1)
result

# %%
sql_text_2 ="""
    SELECT
    percentile_cont(0.90) within group (order by price_pcm asc) as percentile_09  
    from capstone_jmrs.rightmove_clean;
"""

# %% [markdown]
# ### SQL in Python END

# %%
### further code
percentile_cont(0.75) within group (order by price_pcm asc) as percentile_50,
  percentile_cont(0.75) within group (order by price_pcm asc) as percentile_75,
  percentile_cont(0.90) within group (order by price_pcm asc) as percentile_90,
  percentile_cont(0.95) within group (order by price_pcm asc) as percentile_95

# %%
import numpy as np
np.percentile(df_clean['price_per_sqm'],90)
# Out:
# nan

# %%
np.percentile(df_clean.price_per_sqm,90)
# Out:
# nan

# %%
import matplotlib.cbook as cbook
import matplotlib.pyplot as plt
import numpy as np

# Generate some random data to visualise
data = [x for x in df_clean['price_per_sqm'].to_list() if str(x) != 'nan']

stats = {}
# Compute the boxplot stats (as in the default matplotlib implementation)
stats['A'] = cbook.boxplot_stats(data, labels='A')[0]
stats['B'] = cbook.boxplot_stats(data, labels='B')[0]
stats['C'] = cbook.boxplot_stats(data, labels='C')[0]

# For box A compute the 1st and 99th percentiles
stats['A']['q1'], stats['A']['q3'] = np.percentile(data, [1, 99])
# For box B compute the 10th and 90th percentiles
stats['B']['q1'], stats['B']['q3'] = np.percentile(data, [50, 90])
# For box C compute the 25th and 75th percentiles (matplotlib default)
stats['C']['q1'], stats['C']['q3'] = np.percentile(data, [25, 75])

fig, ax = plt.subplots(1, 1)
# Plot boxplots from our computed statistics
bp = ax.bxp([stats['A'], stats['B'], stats['C']], positions=range(3))

# Colour the lines in the boxplot blue
for element in bp.keys():
    plt.setp(bp[element], color='C0')

# %%
np.random.seed(2019)
data_1 = np.random.normal(size=100)

# %%
data = np.array(df_clean['price_per_sqm'].to_list())
data
# Out:
# array([  nan,   nan,   nan, ..., 47.79, 42.31, 39.53])

# %%
cleanedList = [x for x in df_clean['price_per_sqm'].to_list() if str(x) != 'nan']
cleanedList
# Out:
# [52.59,
#  49.51,
#  66.33,
#  64.35,
#  47.45,
#  143.08,
#  104.0,
#  155.24,
#  71.09,
#  54.77,
#  58.35,
#  56.42,
#  95.32,
#  54.17,
#  72.43,
#  35.37,
#  67.13,
#  59.87,
#  53.23,
#  69.33,
#  181.25,
#  1450.0,
#  34.21,
#  58.83,
#  102.94,
#  71.0,
#  85.53,
#  55.44,
#  71.33,
#  63.52,
#  63.52,
#  5.79,
#  65.96,
#  46.05,
#  81.52,
#  57.12,
#  76.75,
#  54.18,
#  41.84,
#  81.77,
#  74.56,
#  392.6,
#  57.18,
#  67.83,
#  77.5,
#  72.5,
#  68.29,
#  163.6,
#  46.24,
#  49.09,
#  41.25,
#  39.06,
#  118.18,
#  47.67,
#  157.77,
#  281.67,
#  214.85,
#  51.13,
#  39.07,
#  82.36,
#  48.08,
#  86.65,
#  50.0,
#  112.5,
#  277.5,
#  116.56,
#  155.24,
#  47.89,
#  52.07,
#  77.6,
#  67.33,
#  428.0,
#  44.92,
#  81.91,
#  94.36,
#  63.01,
#  68.98,
#  51.28,
#  50.49,
#  479.11,
#  75.08,
#  28.29,
#  47.71,
#  81.2,
#  47.62,
#  66.67,
#  40.43,
#  37.74,
#  73.64,
#  52.83,
#  65.79,
#  85.43,
#  55.43,
#  24.62,
#  38.69,
#  59.29,
#  57.63,
#  82.73,
#  38.78,
#  49.51,
#  59.29,
#  69.8,
#  72.44,
#  31.73,
#  430.89,
#  50.0,
#  29.53,
#  102.32,
#  135.71,
#  100.31,
#  39.72,
#  54.16,
#  82.93,
#  62.95,
#  26.68,
#  52.0,
#  47.98,
#  78.24,
#  108.68,
#  64.25,
#  71.75,
#  63.15,
#  78.14,
#  43.51,
#  59.09,
#  83.45,
#  66.5,
#  43.89,
#  36.21,
#  44.57,
#  41.83,
#  479.11,
#  51.59,
#  70.53,
#  84.04,
#  103.58,
#  37.03,
#  51.71,
#  285.11,
#  49.06,
#  46.85,
#  49.8,
#  74.43,
#  89.06,
#  28.3,
#  28.71,
#  43.65,
#  28.44,
#  24.78,
#  39.7,
#  54.17,
#  58.71,
#  84.28,
#  54.17,
#  79.47,
#  58.43,
#  65.0,
#  70.85,
#  102.33,
#  63.52,
#  54.19,
#  60.68,
#  40.91,
#  50.0,
#  47.79,
#  40.63,
#  46.27,
#  45.5,
#  45.98,
#  48.4,
#  42.07,
#  57.42,
#  48.4,
#  36.33,
#  62.6,
#  40.32,
#  37.5,
#  62.55,
#  36.23,
#  32.53,
#  38.4,
#  41.79,
#  67.06,
#  58.5,
#  68.92,
#  60.73,
#  65.49,
#  62.38,
#  62.6,
#  50.3,
#  49.52,
#  30.77,
#  57.6,
#  41.76,
#  62.36,
#  27.33,
#  29.6,
#  44.89,
#  34.88,
#  50.67,
#  68.43,
#  50.33,
#  45.72,
#  51.32,
#  64.29,
#  833.31,
#  45.98,
#  54.93,
#  127.32,
#  59.71,
#  44.96,
#  116.07,
#  68.94,
#  30.05,
#  70.71,
#  44.6,
#  66.6,
#  65.17,
#  86.49,
#  96.49,
#  81.64,
#  79.42,
#  39.49,
#  68.37,
#  78.04,
#  80.35,
#  81.48,
#  52.62,
#  50.77,
#  46.67,
#  53.67,
#  47.02,
#  127.12,
#  67.08,
#  60.87,
#  110.47,
#  73.58,
#  61.38,
#  76.44,
#  94.46,
#  83.7,
#  120.37,
#  66.94,
#  45.39,
#  67.16,
#  52.96,
#  68.49,
#  72.6,
#  129.92,
#  45.65,
#  78.91,
#  95.26,
#  88.44,
#  76.0,
#  47.6,
#  39.8,
#  81.48,
#  54.58,
#  54.69,
#  51.59,
#  42.62,
#  77.31,
#  36.31,
#  39.49,
#  26.37,
#  68.65,
#  103.18,
#  64.2,
#  77.31,
#  32.05,
#  45.03,
#  51.18,
#  76.44,
#  46.43,
#  86.11,
#  69.85,
#  56.11,
#  58.37,
#  79.17,
#  150.61,
#  66.26,
#  63.56,
#  56.38,
#  52.67,
#  94.94,
#  43.42,
#  45.63,
#  77.45,
#  60.18,
#  108.34,
#  133.85,
#  76.44,
#  91.52,
#  36.31,
#  38.24,
#  57.78,
#  42.9,
#  109.07,
#  77.17,
#  26.95,
#  40.99,
#  67.76,
#  65.85,
#  53.06,
#  51.18,
#  114.04,
#  57.78,
#  39.39,
#  101.72,
#  50.0,
#  90.71,
#  65.85,
#  53.38,
#  46.96,
#  65.0,
#  84.72,
#  69.5,
#  77.66,
#  83.39,
#  108.33,
#  90.71,
#  81.58,
#  56.25,
#  45.88,
#  48.97,
#  50.37,
#  63.35,
#  91.94,
#  86.45,
#  66.41,
#  41.9,
#  65.24,
#  125.9,
#  96.22,
#  112.07,
#  112.07,
#  95.69,
#  50.24,
#  58.68,
#  29.84,
#  58.37,
#  67.58,
#  76.44,
#  36.0,
#  57.18,
#  156.0,
#  64.69,
#  61.55,
#  60.21,
#  29.66,
#  51.87,
#  39.82,
#  43.62,
#  70.48,
#  58.77,
#  68.93,
#  43.1,
#  97.89,
#  94.11,
#  124.2,
#  56.03,
#  50.1,
#  75.0,
#  72.41,
#  104.17,
#  45.36,
#  71.91,
#  53.02,
#  54.16,
#  72.41,
#  78.36,
#  41.58,
#  67.34,
#  46.24,
#  77.61,
#  77.68,
#  43.67,
#  33.8,
#  28.79,
#  75.0,
#  70.62,
#  91.16,
#  87.14,
#  46.15,
#  104.24,
#  79.02,
#  73.13,
#  103.45,
#  103.88,
#  35.07,
#  48.3,
#  47.94,
#  174.98,
#  39.26,
#  119.41,
#  52.09,
#  86.86,
#  103.17,
#  98.16,
#  102.86,
#  116.29,
#  80.66,
#  56.42,
#  72.64,
#  81.25,
#  71.9,
#  50.9,
#  58.24,
#  108.33,
#  42.98,
#  60.79,
#  70.65,
#  51.71,
#  78.39,
#  78.29,
#  36.11,
#  74.75,
#  64.75,
#  56.79,
#  99.31,
#  81.25,
#  79.02,
#  74.97,
#  39.68,
#  88.26,
#  65.0,
#  97.01,
#  69.89,
#  55.05,
#  105.43,
#  35.63,
#  30.86,
#  40.7,
#  32.85,
#  72.23,
#  76.33,
#  71.9,
#  79.17,
#  29.81,
#  78.39,
#  86.67,
#  37.82,
#  50.0,
#  43.02,
#  176.0,
#  73.91,
#  91.79,
#  74.08,
#  87.5,
#  56.83,
#  69.61,
#  59.52,
#  137.18,
#  34.13,
#  65.95,
#  49.89,
#  103.18,
#  103.73,
#  105.83,
#  103.18,
#  60.0,
#  63.54,
#  31.43,
#  46.02,
#  92.35,
#  103.33,
#  17.28,
#  32.73,
#  48.85,
#  115.96,
#  91.32,
#  94.15,
#  74.29,
#  65.0,
#  75.0,
#  76.21,
#  50.0,
#  125.71,
#  49.89,
#  34.33,
#  67.87,
#  62.15,
#  102.63,
#  89.83,
#  75.45,
#  64.75,
#  44.6,
#  78.03,
#  38.46,
#  62.22,
#  75.11,
#  42.92,
#  36.62,
#  32.05,
#  1071.43,
#  60.66,
#  30.92,
#  31.16,
#  43.24,
#  41.76,
#  43.62,
#  33.23,
#  36.43,
#  30.98,
#  85.0,
#  58.76,
#  33.54,
#  40.53,
#  74.29,
#  152.94,
#  85.28,
#  44.25,
#  40.04,
#  57.62,
#  70.59,
#  39.22,
#  23.75,
#  25.58,
#  51.02,
#  31.97,
#  61.12,
#  73.82,
#  59.88,
#  30.89,
#  33.33,
#  68.69,
#  29.34,
#  117.97,
#  60.42,
#  67.67,
#  65.2,
#  75.12,
#  28.77,
#  72.71,
#  62.03,
#  54.77,
#  70.2,
#  70.2,
#  70.2,
#  65.81,
#  66.79,
#  139.29,
#  89.27,
#  65.0,
#  69.81,
#  57.78,
#  37.17,
#  83.0,
#  79.44,
#  71.27,
#  73.82,
#  47.28,
#  47.84,
#  81.8,
#  83.0,
#  67.9,
#  90.94,
#  155.69,
#  26.98,
#  41.1,
#  36.52,
#  37.96,
#  28.48,
#  35.05,
#  49.1,
#  42.86,
#  37.36,
#  39.77,
#  82.38,
#  34.75,
#  38.69,
#  55.75,
#  42.86,
#  47.49,
#  51.61,
#  66.29,
#  30.62,
#  35.6,
#  34.67,
#  42.24,
#  47.84,
#  53.61,
#  55.71,
#  62.02,
#  80.43,
#  70.81,
#  60.42,
#  60.44,
#  60.0,
#  51.45,
#  67.22,
#  63.56,
#  58.78,
#  53.49,
#  48.94,
#  80.36,
#  70.0,
#  47.68,
#  61.24,
#  35.52,
#  37.56,
#  50.0,
#  51.85,
#  35.56,
#  60.73,
#  38.45,
#  30.72,
#  18.52,
#  34.48,
#  41.77,
#  46.43,
#  28.66,
#  40.76,
#  28.89,
#  37.32,
#  34.62,
#  38.89,
#  71.34,
#  64.29,
#  58.28,
#  57.88,
#  63.34,
#  47.49,
#  71.5,
#  60.14,
#  58.77,
#  72.41,
#  64.75,
#  75.0,
#  73.13,
#  77.46,
#  98.48,
#  47.88,
#  62.6,
#  52.11,
#  27.09,
#  39.19,
#  60.66,
#  81.25,
#  107.0,
#  47.42,
#  39.31,
#  37.14,
#  65.0,
#  129.33,
#  61.4,
#  46.63,
#  17.12,
#  42.21,
#  55.28,
#  58.21,
#  58.44,
#  53.02,
#  59.09,
#  49.74,
#  39.68,
#  54.17,
#  56.83,
#  42.06,
#  37.21,
#  1665.0,
#  1665.0,
#  32.76,
#  61.29,
#  44.69,
#  53.54,
#  64.6,
#  141.75,
#  138.1,
#  69.89,
#  49.92,
#  101.02,
#  39.07,
#  64.12,
#  63.21,
#  63.59,
#  62.23,
#  66.13,
#  61.91,
#  65.0,
#  61.03,
#  44.23,
#  64.36,
#  41.43,
#  49.06,
#  79.75,
#  52.48,
#  47.56,
#  60.94,
#  63.04,
#  74.81,
#  43.86,
#  35.03,
#  121.24,
#  48.57,
#  72.76,
#  54.18,
#  54.18,
#  52.2,
#  47.1,
#  235.34,
#  106.58,
#  62.39,
#  79.45,
#  67.03,
#  69.64,
#  36.62,
#  50.0,
#  39.63,
#  50.83,
#  75.52,
#  47.75,
#  75.5,
#  51.42,
#  92.41,
#  35.86,
#  54.17,
#  73.69,
#  36.45,
#  47.27,
#  43.35,
#  33.93,
#  34.72,
#  37.74,
#  42.32,
#  53.31,
#  46.94,
#  60.2,
#  45.97,
#  47.07,
#  54.93,
#  44.65,
#  47.79,
#  44.83,
#  54.17,
#  46.63,
#  71.67,
#  49.12,
#  49.67,
#  56.22,
#  51.48,
#  68.22,
#  52.59,
#  52.53,
#  43.7,
#  45.69,
#  56.88,
#  65.67,
#  47.88,
#  63.41,
#  64.05,
#  53.13,
#  155.24,
#  178.84,
#  64.19,
#  50.71,
#  76.14,
#  44.52,
#  60.56,
#  46.71,
#  48.52,
#  57.57,
#  64.34,
#  67.47,
#  47.74,
#  44.62,
#  43.66,
#  83.87,
#  125.81,
#  46.63,
#  56.88,
#  49.84,
#  46.05,
#  56.88,
#  73.69,
#  47.81,
#  42.24,
#  61.13,
#  72.43,
#  64.48,
#  37.63,
#  57.97,
#  57.45,
#  39.99,
#  125.86,
#  44.29,
#  4.38,
#  45.14,
#  40.6,
#  55.86,
#  51.72,
#  56.97,
#  56.48,
#  69.33,
#  42.87,
#  87.37,
#  65.35,
#  62.21,
#  37.0,
#  50.57,
#  54.17,
#  164.81,
#  46.15,
#  58.61,
#  44.47,
#  50.83,
#  71.63,
#  49.24,
#  50.56,
#  58.47,
#  50.17,
#  53.38,
#  54.82,
#  52.17,
#  54.64,
#  64.33,
#  61.91,
#  42.91,
#  45.61,
#  45.64,
#  42.76,
#  96.15,
#  52.92,
#  71.41,
#  104.0,
#  83.26,
#  61.49,
#  130.75,
#  106.05,
#  118.18,
#  33.7,
#  115.12,
#  37.47,
#  46.39,
#  75.0,
#  37.8,
#  29.35,
#  40.37,
#  35.0,
#  46.62,
#  58.78,
#  88.3,
#  69.64,
#  79.41,
#  56.8,
#  58.67,
#  65.82,
#  65.77,
#  63.8,
#  65.51,
#  53.01,
#  64.63,
#  56.0,
#  79.44,
#  98.49,
#  115.25,
#  112.76,
#  52.87,
#  38.39,
#  59.09,
#  39.77,
#  68.49,
#  43.92,
#  54.17,
#  61.29,
#  23.96,
#  37.5,
#  41.7,
#  40.21,
#  33.09,
#  112.68,
#  44.48,
#  56.17,
#  39.22,
#  47.46,
#  50.85,
#  68.03,
#  66.67,
#  48.05,
#  57.99,
#  49.95,
#  61.56,
#  45.72,
#  51.68,
#  73.27,
#  94.2,
#  54.58,
#  50.0,
#  52.32,
#  50.74,
#  48.16,
#  41.57,
#  41.57,
#  52.72,
#  48.36,
#  71.07,
#  51.46,
#  54.58,
#  171.96,
#  47.93,
#  91.41,
#  38.02,
#  90.75,
#  50.88,
#  74.52,
#  55.56,
#  67.91,
#  46.43,
#  56.17,
#  34.91,
#  81.7,
#  106.74,
#  50.57,
#  39.61,
#  49.92,
#  56.48,
#  66.66,
#  60.9,
#  90.71,
#  67.83,
#  47.93,
#  76.44,
#  76.27,
#  37.58,
#  65.0,
#  42.04,
#  44.59,
#  50.21,
#  36.11,
#  74.9,
#  59.96,
#  69.5,
#  94.94,
#  1200.0,
#  44.1,
#  35.89,
#  74.07,
#  35.0,
#  49.84,
#  35.18,
#  50.86,
#  30.78,
#  36.26,
#  47.56,
#  60.41,
#  47.68,
#  56.8,
#  46.62,
#  87.23,
#  81.18,
#  81.25,
#  37.86,
#  57.97,
#  70.65,
#  36.31,
#  53.76,
#  152.58,
#  70.19,
#  39.15,
#  48.37,
#  73.45,
#  70.19,
#  50.16,
#  55.97,
#  68.79,
#  48.66,
#  50.83,
#  70.27,
#  42.14,
#  65.0,
#  180.99,
#  51.7,
#  75.58,
#  47.93,
#  69.5,
#  72.48,
#  51.88,
#  45.14,
#  36.89,
#  60.61,
#  32.5,
#  35.86,
#  40.57,
#  68.33,
#  57.78,
#  52.46,
#  51.05,
#  77.38,
#  67.45,
#  75.09,
#  72.79,
#  42.48,
#  144.72,
#  32.82,
#  67.28,
#  66.93,
#  42.68,
#  44.09,
#  57.25,
#  48.44,
#  ...]

# %%
data_1
# Out:
# array([-0.21767896,  0.82145535,  1.48127781,  1.33186404, -0.36186537,
#         0.68560883,  0.57376143,  0.28772767, -0.23563426,  0.95349024,
#        -1.6896253 , -0.34494271,  0.0169049 , -0.51498352,  0.24450929,
#        -0.18931261,  2.67217242,  0.46480249,  0.84593044, -0.50354158,
#        -0.96333553,  0.06496863, -3.20504023,  1.05496943,  0.80727669,
#         0.47414055,  0.41092825,  0.48668927, -0.53552971, -0.83890794,
#        -0.81237482, -0.45079294,  1.07080136,  0.21742115, -1.17585859,
#        -0.92611679, -0.99394766,  0.58680631,  1.06381324,  0.23774086,
#        -0.77505656, -0.97910395, -1.54936294, -1.20682824,  0.44500823,
#        -0.17308621,  1.48894719, -0.79252049,  1.8389971 , -0.43936212,
#         1.16000317, -0.57709345, -1.0310444 , -0.83888545,  0.31693406,
#         0.35325398,  1.51572304, -0.37785023, -1.09267955, -0.64834252,
#         1.47998549, -2.10530069,  0.22869489,  0.36062884, -1.43988653,
#        -0.66270577, -0.66163722, -0.59599698,  0.05219505, -1.55332683,
#         1.65425776,  0.65685868, -0.53856594, -0.99684778, -1.73212696,
#        -1.66017338,  0.23508278,  0.11515449, -2.55938452, -0.23332046,
#         0.59316742,  1.4717105 , -0.23423896, -0.08445903,  0.26334763,
#        -0.5169208 ,  1.08250174, -0.68891406, -1.05726513,  0.47787975,
#        -0.69237606, -0.77757385,  0.21154881, -0.27592737, -0.20624515,
#        -0.52948817, -0.37231224, -1.84080404,  0.28970762, -1.35265794])

# %%
# remove row where price is NaN
df_overview = df_overview[df_overview.platform_id != '122820101']

# %%
df_overview
# Out:
#      platform_id   platform           neighbourhood  prices_pcm scraping_date
# 0      127236689  Rightmove  Hammersmith and Fulham      3683.0    2022-09-23
# 1      127366049  Rightmove  Hammersmith and Fulham      3750.0    2022-09-23
# 2      127365830  Rightmove  Hammersmith and Fulham      2600.0    2022-09-23
# 3      126019895  Rightmove  Hammersmith and Fulham      1350.0    2022-09-23
# 4      127361573  Rightmove  Hammersmith and Fulham      1750.0    2022-09-23
# ...          ...        ...                     ...         ...           ...
# 6669   125689532  Rightmove               Islington      1950.0    2022-09-23
# 6670   125664206  Rightmove               Islington      5500.0    2022-09-23
# 6671   124925873  Rightmove               Islington      2817.0    2022-09-23
# 6672    65417791  Rightmove               Islington      1582.0    2022-09-23
# 6673   127368341  Rightmove               Islington      1647.0    2022-09-23
#
# [6674 rows x 5 columns]

# %%
df_details
# Out:
#      platform_id  bedrooms  bathrooms  size_sqm property_type available_from  \
# 0      127236689       2.0        1.0       NaN     Apartment      Ask agent
# 1      120584393       2.0        2.0       NaN     Apartment      Ask agent
# 2      127259195       2.0        2.0       NaN          Flat      Ask agent
# 3      126142214       3.0        2.0      89.0          Flat      Ask agent
# 4      126136184       1.0        1.0      37.0          Flat      Ask agent
# ...          ...       ...        ...       ...           ...            ...
# 6585   125628233       5.0        3.0       NaN         House            Now
# 6586   125382389       5.0        3.0       NaN    Town House            Now
# 6587   127170005       3.0        2.0       NaN            NA            Now
# 6588    85085181       3.0        2.0       NaN          Flat            Now
# 6589   122550623       2.0        2.0       NaN          Flat            Now
#
#        let_type                                  furnished_orig  \
# 0     Long term  Furnished or unfurnished, landlord is flexible
# 1     Long term  Furnished or unfurnished, landlord is flexible
# 2     Long term                                  Part furnished
# 3     Long term                                  Part furnished
# 4     Long term                                  Part furnished
# ...         ...                                             ...
# 6585  Long term                                     Unfurnished
# 6586  Long term                                     Unfurnished
# 6587  Long term                                     Unfurnished
# 6588  Long term                                     Unfurnished
# 6589  Long term                                     Unfurnished
#
#      available_today simple_prop_type    furniture
# 0            unclear        Apartment    Furnished
# 1            unclear        Apartment    Furnished
# 2            unclear            Other  Unfurnished
# 3            unclear            Other  Unfurnished
# 4            unclear            Other  Unfurnished
# ...              ...              ...          ...
# 6585       available            Other  Unfurnished
# 6586       available            Other  Unfurnished
# 6587       available            Other  Unfurnished
# 6588       available            Other  Unfurnished
# 6589       available            Other  Unfurnished
#
# [6574 rows x 11 columns]

# %%
# concat doesn't work, because of different index
df_total = pd.merge(df_overview, df_details, on='platform_id', how='left')

# %%
df_total
# Out:
#      platform_id   platform           neighbourhood  prices_pcm scraping_date  \
# 0      127236689  Rightmove  Hammersmith and Fulham      3683.0    2022-09-23
# 1      127366049  Rightmove  Hammersmith and Fulham      3750.0    2022-09-23
# 2      127365830  Rightmove  Hammersmith and Fulham      2600.0    2022-09-23
# 3      126019895  Rightmove  Hammersmith and Fulham      1350.0    2022-09-23
# 4      127361573  Rightmove  Hammersmith and Fulham      1750.0    2022-09-23
# ...          ...        ...                     ...         ...           ...
# 6669   125689532  Rightmove               Islington      1950.0    2022-09-23
# 6670   125664206  Rightmove               Islington      5500.0    2022-09-23
# 6671   124925873  Rightmove               Islington      2817.0    2022-09-23
# 6672    65417791  Rightmove               Islington      1582.0    2022-09-23
# 6673   127368341  Rightmove               Islington      1647.0    2022-09-23
#
#       bedrooms  bathrooms  size_sqm property_type available_from   let_type  \
# 0          2.0        1.0       NaN     Apartment      Ask agent  Long term
# 1          3.0        2.0       NaN         House     31/10/2022  Long term
# 2          2.0        2.0       NaN          Flat      Ask agent  Long term
# 3          1.0        1.0      40.0          Flat     03/10/2022  Long term
# 4          NaN        1.0       NaN     Apartment     30/09/2022  Long term
# ...        ...        ...       ...           ...            ...        ...
# 6669       1.0        1.0      37.0          Flat      Ask agent  Long term
# 6670       3.0        3.0       NaN          Flat     01/11/2022  Long term
# 6671       2.0        2.0      74.0          Flat      Ask agent  Long term
# 6672       1.0        NaN       NaN          Flat            Now  Long term
# 6673       1.0        1.0       NaN          Flat      Ask agent  Long term
#
#                                       furnished_orig available_today  \
# 0     Furnished or unfurnished, landlord is flexible         unclear
# 1     Furnished or unfurnished, landlord is flexible        occupied
# 2                                          Furnished         unclear
# 3                                          Furnished        occupied
# 4                                          Furnished        occupied
# ...                                              ...             ...
# 6669                                  Part furnished         unclear
# 6670                                  Part furnished        occupied
# 6671                                  Part furnished         unclear
# 6672                                  Part furnished       available
# 6673                                  Part furnished         unclear
#
#      simple_prop_type    furniture
# 0           Apartment    Furnished
# 1               Other    Furnished
# 2               Other    Furnished
# 3               Other    Furnished
# 4           Apartment    Furnished
# ...               ...          ...
# 6669            Other  Unfurnished
# 6670            Other  Unfurnished
# 6671            Other  Unfurnished
# 6672            Other  Unfurnished
# 6673            Other  Unfurnished
#
# [6674 rows x 15 columns]

# %%
# create column with relative price (price per sqm)
df_total['price_per_sqm'] = round((df_total['price_pcm']/df_total['size_sqm']), 2)

# %%
df_total['price_per_bedroom'] = round((df_total['price_pcm']/df_total['bedrooms']), 2)

##Zwei Spalten dividieren und Nullwerte ignorieren:
def my_func(x):
    try:
        return int(x['price_pcm']) / int(x['size_sqm'])
    except (ZeroDivisionError, ValueError):
        return int(x['price_pcm']) / 1

df["price_per_sqm"] = df.apply(my_func, axis=1)

# %%
df_total.head(20)
# Out:
#    platform_id   platform           neighbourhood  price_pcm scraping_date  \
# 0    127334450  Rightmove  Hammersmith and Fulham     4116.0    2022-09-23
# 1    127366049  Rightmove  Hammersmith and Fulham     3750.0    2022-09-23
# 2    126233582  Rightmove  Hammersmith and Fulham     1949.0    2022-09-23
# 3    126019895  Rightmove  Hammersmith and Fulham     1350.0    2022-09-23
# 4    127361573  Rightmove  Hammersmith and Fulham     1750.0    2022-09-23
# 5    127361126  Rightmove  Hammersmith and Fulham     3445.0    2022-09-23
# 6    127359260  Rightmove  Hammersmith and Fulham    13000.0    2022-09-23
# 7    121796000  Rightmove  Hammersmith and Fulham     6500.0    2022-09-23
# 8    127328657  Rightmove  Hammersmith and Fulham     2817.0    2022-09-23
# 9    127349303  Rightmove  Hammersmith and Fulham     2000.0    2022-09-23
# 10   127080395  Rightmove  Hammersmith and Fulham     2400.0    2022-09-23
# 11   127348616  Rightmove  Hammersmith and Fulham     1101.0    2022-09-23
# 12   127347230  Rightmove  Hammersmith and Fulham     2123.0    2022-09-23
# 13   127345106  Rightmove  Hammersmith and Fulham     3012.0    2022-09-23
# 14   127322207  Rightmove  Hammersmith and Fulham     3000.0    2022-09-23
# 15   127341047  Rightmove  Hammersmith and Fulham     6500.0    2022-09-23
# 16    84462349  Rightmove  Hammersmith and Fulham     1841.0    2022-09-23
# 17   127321760  Rightmove  Hammersmith and Fulham     4117.0    2022-09-23
# 18   127321583  Rightmove  Hammersmith and Fulham     2817.0    2022-09-23
# 19   127333439  Rightmove  Hammersmith and Fulham     3250.0    2022-09-23
#
#     bedrooms  bathrooms  size_sqm property_type available_from    let_type  \
# 0        2.0        2.0       NaN     Apartment     2022-09-23   Long term
# 1        3.0        2.0       NaN         House     2022-10-31   Long term
# 2        1.0        1.0       NaN          Flat     2022-09-23   Long term
# 3        1.0        1.0      40.0          Flat     2022-10-03   Long term
# 4        NaN        1.0       NaN     Apartment     2022-09-30   Long term
# 5        2.0        2.0       NaN     Apartment     2022-10-03   Long term
# 6        3.0        3.0     215.0         House     2022-10-03  Short term
# 7        6.0        2.0       NaN      Terraced     2022-09-23   Long term
# 8        1.0        1.0       NaN          Flat     2022-09-23   Long term
# 9        1.0        1.0      52.0          Flat     2022-12-07   Long term
# 10       2.0        1.0       NaN          Flat     2022-10-21   Long term
# 11       NaN        NaN       NaN     Apartment     2022-10-03   Long term
# 12       2.0        2.0       NaN          Flat     2022-11-15   Long term
# 13       1.0        1.0       NaN     Apartment     2022-11-14   Long term
# 14       2.0        2.0       NaN          Flat     2022-09-23  Short term
# 15       2.0        2.0       NaN          Flat     2022-10-21  Short term
# 16       2.0        1.0       NaN     Apartment     2022-11-08   Long term
# 17       2.0        2.0       NaN     Apartment     2022-09-23   Long term
# 18       1.0        1.0       NaN     Apartment     2022-09-23   Long term
# 19       2.0        2.0       NaN     Apartment     2022-10-07   Long term
#
#                                     furnished_orig available_today  \
# 0                                        Furnished       available
# 1   Furnished or unfurnished, landlord is flexible        occupied
# 2                                        Furnished       available
# 3                                        Furnished        occupied
# 4                                        Furnished        occupied
# 5                                        Furnished        occupied
# 6                                        Furnished        occupied
# 7                                        Furnished       available
# 8   Furnished or unfurnished, landlord is flexible       available
# 9                                        Furnished        occupied
# 10                                       Furnished        occupied
# 11                                       Furnished        occupied
# 12                                       Furnished        occupied
# 13                                       Furnished        occupied
# 14                                       Furnished       available
# 15                                       Furnished        occupied
# 16                                       Furnished        occupied
# 17                                       Furnished       available
# 18                                       Furnished       available
# 19                                       Furnished        occupied
#
#    simple_prop_type  furniture  price_per_sqm title  price_per_bedroom
# 0         Apartment  Furnished            NaN  None            2058.00
# 1             Other  Furnished            NaN  None            1250.00
# 2             Other  Furnished            NaN  None            1949.00
# 3             Other  Furnished          33.75  None            1350.00
# 4         Apartment  Furnished            NaN  None                NaN
# 5         Apartment  Furnished            NaN  None            1722.50
# 6             Other  Furnished          60.47  None            4333.33
# 7             Other  Furnished            NaN  None            1083.33
# 8             Other  Furnished            NaN  None            2817.00
# 9             Other  Furnished          38.46  None            2000.00
# 10            Other  Furnished            NaN  None            1200.00
# 11        Apartment  Furnished            NaN  None                NaN
# 12            Other  Furnished            NaN  None            1061.50
# 13        Apartment  Furnished            NaN  None            3012.00
# 14            Other  Furnished            NaN  None            1500.00
# 15            Other  Furnished            NaN  None            3250.00
# 16        Apartment  Furnished            NaN  None             920.50
# 17        Apartment  Furnished            NaN  None            2058.50
# 18        Apartment  Furnished            NaN  None            2817.00
# 19        Apartment  Furnished            NaN  None            1625.00

# %%
df_total.price_per_sqm.query('platform_id == "126019895"')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/ruben/neuefische_rp/capstone/capstone-ukio-rep/rightmove_ruben_3_details.ipynb Cell 34 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/ruben/neuefische_rp/capstone/capstone-ukio-rep/rightmove_ruben_3_details.ipynb#X50sZmlsZQ%3D%3D?line=0'>1</a> df_total.price_per_sqm.query('platform_id == "126019895"')
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'query'

# %%
# import the data frame to DBeaver

# call the schema created for this project
schema = 'capstone_jmrs'
# get the function to connect to the database
engine = get_engine()

# give the table a unique name
table_name = 'rightmove_total'

# import the table to sql
if engine!=None:
    try:
        df_total.to_sql(name=table_name,
                        con=engine,
                        if_exists='replace',
                        schema=schema, 
                        index=False,
                        chunksize=5000, 
                        method='multi')
        print(f"The {table_name} table was imported successfully.")
    
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        engine = None
# Out:
# The rightmove_total table was imported successfully.

# %%
schema = 'capstone_jmrs'

sql = f"""
SELECT *
FROM {schema}.rightmove_total
"""

df_total = get_dataframe(sql)
df_total
# Out:
#      platform_id   platform           neighbourhood  price_pcm scraping_date  \
# 0      127334450  Rightmove  Hammersmith and Fulham     4116.0    2022-09-23
# 1      127366049  Rightmove  Hammersmith and Fulham     3750.0    2022-09-23
# 2      126233582  Rightmove  Hammersmith and Fulham     1949.0    2022-09-23
# 3      126019895  Rightmove  Hammersmith and Fulham     1350.0    2022-09-23
# 4      127361573  Rightmove  Hammersmith and Fulham     1750.0    2022-09-23
# ...          ...        ...                     ...        ...           ...
# 6568   125988470  Rightmove               Islington     1712.0    2022-09-23
# 6569   125942000  Rightmove               Islington     2579.0    2022-09-23
# 6570   125689532  Rightmove               Islington     1950.0    2022-09-23
# 6571   124925873  Rightmove               Islington     2817.0    2022-09-23
# 6572   127368341  Rightmove               Islington     1647.0    2022-09-23
#
#       bedrooms  bathrooms  size_sqm property_type available_from   let_type  \
# 0          2.0        2.0       NaN     Apartment     2022-09-23  Long term
# 1          3.0        2.0       NaN         House     2022-10-31  Long term
# 2          1.0        1.0       NaN          Flat     2022-09-23  Long term
# 3          1.0        1.0      40.0          Flat     2022-10-03  Long term
# 4          NaN        1.0       NaN     Apartment     2022-09-30  Long term
# ...        ...        ...       ...           ...            ...        ...
# 6568       0.0        1.0      37.0        Studio           None  Long term
# 6569       2.0        1.0      72.0          Flat           None  Long term
# 6570       1.0        1.0      37.0          Flat           None  Long term
# 6571       2.0        2.0      74.0          Flat           None  Long term
# 6572       1.0        1.0       NaN          Flat           None  Long term
#
#                                       furnished_orig available_today  \
# 0                                          Furnished       available
# 1     Furnished or unfurnished, landlord is flexible        occupied
# 2                                          Furnished       available
# 3                                          Furnished        occupied
# 4                                          Furnished        occupied
# ...                                              ...             ...
# 6568                                  Part furnished         unclear
# 6569                                  Part furnished         unclear
# 6570                                  Part furnished         unclear
# 6571                                  Part furnished         unclear
# 6572                                  Part furnished         unclear
#
#      simple_prop_type    furniture  price_per_sqm title
# 0           Apartment    Furnished            NaN  None
# 1               Other    Furnished            NaN  None
# 2               Other    Furnished            NaN  None
# 3               Other    Furnished      33.750000  None
# 4           Apartment    Furnished            NaN  None
# ...               ...          ...            ...   ...
# 6568           Studio  Unfurnished      46.270270  None
# 6569            Other  Unfurnished      35.819444  None
# 6570            Other  Unfurnished      52.702703  None
# 6571            Other  Unfurnished      38.067568  None
# 6572            Other  Unfurnished            NaN  None
#
# [6573 rows x 17 columns]

# %%
page = requests.get(f"https://www.rightmove.co.uk/properties/71421558#/?channel=RES_LET")
html = page.content
bs = BeautifulSoup(html, 'html.parser')

bedrooms, bathrooms, size, property_type = 'NA', 'NA', 'NA', 'NA' 
row_dict = {'property_id':id, 'bedrooms': bedrooms, 'bathrooms': bathrooms, 'size_sqm': size, 'property_type': property_type}
# get details
details = bs.find(
    'div', class_='_4hBezflLdgDMdFtURKTWh')

details_lst = (detail.get_text() for detail in details)
details_lst = [detail.strip() for detail in details_lst]

#df_details_complete = pd.DataFrame()
# bedrooms, bathrooms, size, property_type = 'NA', 'NA', 'NA', 'NA' 
# row_dict = {'property_id':id, 'bedrooms': bedrooms, 'bathrooms': bathrooms, 'size': size, 'property_type': property_type}
for detail in details_lst:
    if 'TYPE' in detail:
        row_dict['property_type'] = detail.removeprefix('PROPERTY TYPE')
    elif 'BEDROOMS' in detail:
        row_dict['bedrooms'] = detail.removeprefix('BEDROOMS×')
    elif 'BATHROOM' in detail:
        row_dict['bathrooms'] = detail.removeprefix('BATHROOMS×')
    elif 'SIZE' in detail:
        row_dict['size'] = re.search(r'\((.*?)\)', str(detail)).group(1).removesuffix(' sq. m.').replace(',', '').split('-')[0] #grabs lower number, if size is given as a range ################## NON MVP APPROACH tbd?


df_details = pd.DataFrame(row_dict, index=[0])

# %%
df_details
# Out:
#               property_id bedrooms bathrooms size_sqm property_type size
# 0  <built-in function id>       10         7       NA         House  551

# %%
details_lst
# Out:
# ['PROPERTY TYPEHouse',
#  'BEDROOMS×10',
#  'BATHROOMS×7',
#  'SIZE5,930 sq. ft.(551 sq. m.)']
