# %% [markdown]
# Import Libraries

# %%
import time
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import numpy as np

# %% [markdown]
# Insert WebLink

# %% [markdown]
# /furnished-apartments-london-uk/london-croydon-202
#
# /furnished-apartments-london-uk/london-bayswater-046

# %%
weblink = 'https://www.theblueground.com'
pagesite = '/furnished-apartments-london-uk/london-bayswater-046'
page = requests.get(weblink + pagesite)
html = page.content

print(weblink + pagesite)

# %% [markdown]
# Start BeautifulSoup

# %%
# parse the html and save it into a BeautifulSoup instance
bs = BeautifulSoup(html, 'html.parser')
soup = BeautifulSoup(html, 'html.parser')

# %%
print(bs.prettify())

# %% [markdown]
# Here are some simple ways to navigate that data structure:

# %%
soup.title

# %%
soup.title.name

# %%
soup.title.string

# %%
soup.title.parent.name

# %%
soup.p

# %%
soup.p['class']

# %%
soup.a

# %%
soup.find_all('a')

# %%
soup.find(id="link3")

# %%
soup.find_all('span')

# %%
soup.find_all('div')

# %%
soup.find_all('div', class_='bg-wrapper bg-container-fluid lt-gutter--top-inline lt-gutter--bottom')

# %%
title = soup.find("meta", property="og:title")
url = soup.find("meta", property="og:url")

print(title["content"] if title else "No meta title given")
print(url["content"] if url else "No meta url given")

# %%
# import libraries
import urllib.request
from bs4 import BeautifulSoup
# specify the url
urlpage = 'https://www.theblueground.com/furnished-apartments-london-uk/london-bayswater-046' 
print(urlpage)
# query the website and return the html to the variable 'page'
page = urllib.request.urlopen(urlpage)
# parse the html using beautiful soup and store in variable 'soup'
soup = BeautifulSoup(page, 'html.parser')
# find product items
# at time of publication, Nov 2018:
# results = soup.find_all('div', attrs={'class': 'listing category_templates clearfix productListing'})
# updated Nov 2019:
results = soup.find_all('div', attrs={'class': 'property__amenities-list-item'})
print('Number of results', len(results))

# %%
from bs4 import BeautifulSoup
import requests
 
resp = requests.get('https://www.theblueground.com/furnished-apartments-london-uk/london-bayswater-046')
 
html = resp.content
soup = BeautifulSoup(html)
 
option_tags = soup.find_all("script")
option_tags

# %%
soup = bs4.BeautifulSoup(html_string, features="html.parser")
test = soup.findAll('script')
blah = [x.strip() for x in test[0].string.split('\n') if x.strip()]
blah

# %%
soup = bs4.BeautifulSoup(html_string, features="html.parser")
test = soup.findAllNext('script')
blah = [x.strip() for x in test[0].text.split('\n') if x.strip()]
blah
test

# %%
blah = soup.findAllNext('script')
blah2 = [x.strip() for x in test[0].string.split('\n') if x.strip()]
blah2

# %%
# import libraries
import urllib.request
from bs4 import BeautifulSoup
# specify the url
urlpage = 'https://www.theblueground.com/furnished-apartments-london-uk/london-bayswater-046' 
print(urlpage)
# query the website and return the html to the variable 'page'
page = urllib.request.urlopen(urlpage)
# parse the html using beautiful soup and store in variable 'soup'
soup = BeautifulSoup(page, 'html.parser')
# find product items
# at time of publication, Nov 2018:
# results = soup.find_all('div', attrs={'class': 'listing category_templates clearfix productListing'})
# updated Nov 2019:
results = soup.find_all('div', attrs={'span': 'property__amenities-list-item'})
print('Number of results', len(results))

# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

page = 'https://www.theblueground.com/furnished-apartments-london-uk/london-mayfair-094' 
website = requests.get(page)
results = BeautifulSoup(website.content, 'html.parser')

blogbeitraege = results.findAll('div', class_='property__amenities-list-item')
blogbeitraege = results.findAll()

blogbeitraege_lst = (blogbeitrag.get_text() for blogbeitrag in blogbeitraege)
blogbeitraege_lst = [blogbeitrag.strip() for blogbeitrag in blogbeitraege_lst]

df = pd.DataFrame(blogbeitraege_lst, columns=['details'])

# %%
results
# Out:
# <!DOCTYPE html>
#  <html lang="en"> <head> <meta charset="utf-8"/> <meta content="IE=edge, chrome=1" http-equiv="X-UA-Compatible"/> <meta content="noindex" name="robots"/> <script>  var dataLayer = [{
#       country: 'GBR',
#       city: 'LON',
#       pageType: 'propertyDetails',
#       propertyId: '17997',
#       propertyCode:'LON-94',
#       neighborhood: 'Mayfair',
#       numberOfBedrooms: 0 }]; </script> <title>Green St - Apartment for Rent in Mayfair, London | Blueground</title> <meta content="Rent a fully furnished apartment in Mayfair, London. This serviced apartment for rent has property ID 94 and is suitable for long-term accommodation." name="description"/> <meta content="604800" property="og:ttl"/> <meta content="https://www.theblueground.com/furnished-apartments-london-uk/london-mayfair-094" property="og:url"/> <meta content="website" property="og:type"/> <meta content="Green St - Apartment for Rent in Mayfair, London | Blueground" property="og:title"/> <meta content="Rent a fully furnished apartment in Mayfair, London. This serviced apartment for rent has property ID 94 and is suitable for long-term accommodation." property="og:description"/> <meta content="https://photos2.theblueground.com/736/pg17997-o-d1edee23-f052-cd77-60f0-611bf3263402.jpg" property="og:image"/> <meta content="summary" name="twitter:card"/> <meta content="https://www.theblueground.com/furnished-apartments-london-uk/london-mayfair-094" name="twitter:site"/> <meta content="https://twitter.com/theblueground" name="twitter:url"/> <meta content="Green St - Apartment for Rent in Mayfair, London | Blueground" name="twitter:title"/> <meta content="Rent a fully furnished apartment in Mayfair, London. This serviced apartment for rent has property ID 94 and is suitable for long-term accommodation." name="twitter:description"/> <meta content="https://photos2.theblueground.com/736/pg17997-o-d1edee23-f052-cd77-60f0-611bf3263402.jpg" name="twitter:image"/> <link href="https://www.theblueground.com/furnished-apartments-london-uk/london-mayfair-094" rel="canonical"/> <script> var Blueground = Blueground || {}
#   Blueground.configuration = {"path":"/furnished-apartments-london-uk/london-mayfair-094","language":"en","businessConfiguration":{"cx":{"phone":"+44 203 745 9691"},"sales":{"phone":"+44 203 745 9690","email":"sales-lon@theblueground.com"},"info":{"email":"info-lon@theblueground.com","phone":"","whatsapp":"+44 730 939 8025"},"payments":{"email":"payments-lon@theblueground.com"},"onboard":{"email":"bd-lon@theblueground.com"},"inclusive":{}},"csrfToken":"vBiawJZt-MrQBSWLutoc2wSYupwAis92cJVg","currency":"GBP","environment":"production","multilingual":false,"multiCurrency":true,"notifications":[],"websiteUrl":"https://www.theblueground.com","featureFlags":{"disabledCities":"BRU","citiesWithoutSecurityDeposit":"BOS,CHI,WDC","isE2EMode":false},"isLoggedIn":false,"galleryKey":"REIwQUUxRDgtRjk2MTQ5QUYtOTVBQ0VBQTUtNjRGOUZFQUQ="};
#   Blueground.env = {
#     NODE_ENV: 'production',
#     SENTRY_RELEASE_VERSION: 'd8e73110131d71fe1be62b013023403853e430df',
#     SENTRY_CLIENT_DSN: 'https://464c63637a154718961892182d7b0cd3@sentry.io/1387058'
#   } </script> <script> var Blueground = Blueground || {}
#   var dataLayer = (function() {
#     var user = Blueground.configuration.user;
#     var userId = {userId: user && user.id};
#
#     if (dataLayer) {
#       return [userId].concat(dataLayer);
#     }
#
#     return [userId];
#   })(); </script> <script> (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#       new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#       j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#       'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer', 'GTM-M2VZ79W'); </script> <meta content="width=device-width,initial-scale=1" name="viewport"/> <meta content="#273656" name="theme-color"/> <meta content="yes" name="apple-mobile-web-app-capable"/> <meta content="#273656" name="apple-mobile-web-app-status-bar-style"/> <meta content="#273656" name="msapplication-navbutton-color"/> <meta content="#FFFFFF" name="msapplication-TileColor"/> <link href="/manifest.json" rel="manifest"/> <link href="/apple-touch-icon.png" rel="apple-touch-icon"/> <link href="/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/> <link href="/apple-touch-icon-167x167.png" rel="apple-touch-icon" sizes="167x167"/> <link href="/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/> <link href="https://cdn.theblueground.com/website/static/img/favicon-196x196.ecf446215192279d200c.png" rel="icon" sizes="196x196" type="image/png"/> <link href="https://cdn.theblueground.com/website/static/img/favicon-96x96.5dfe2e7570189ed22609.png" rel="icon" sizes="96x96" type="image/png"/> <link href="https://cdn.theblueground.com/website/static/img/favicon-32x32.a04e4b77c282c0bb7763.png" rel="icon" sizes="32x32" type="image/png"/> <link href="https://cdn.theblueground.com/website/static/img/favicon-16x16.3eb9b0423ded6eb1bf1e.png" rel="icon" sizes="16x16" type="image/png"/> <link href="https://cdn.theblueground.com/website/static/img/favicon-128.2ed4dce841c90cf6bd2c.png" rel="icon" sizes="128x128" type="image/png"/> <meta content="https://cdn.theblueground.com/website/static/img/mstile-144x144.736657859e3bfe79bc3b.png" name="msapplication-TileImage"/> <meta content="https://cdn.theblueground.com/website/static/img/mstile-70x70.57c78721eb7ef0493740.png" name="msapplication-square70x70logo"/> <meta content="https://cdn.theblueground.com/website/static/img/mstile-150x150.9e4625724c29993049cf.png" name="msapplication-square150x150logo"/> <meta content="https://cdn.theblueground.com/website/static/img/mstile-310x150.43e23efd8521c838d00e.png" name="msapplication-wide310x150logo"/> <meta content="https://cdn.theblueground.com/website/static/img/mstile-310x310.3ed4330cffbf5cb270b7.png" name="msapplication-square310x310logo"/> <link href="https://www.googletagmanager.com" rel="dns-prefetch"/> <link href="https://use.typekit.net" rel="preconnect"/> <link href="https://cdn.theblueground.com" rel="preconnect"/> <link crossorigin="" href="https://photos2.theblueground.com" rel="preconnect"/> <link as="style" href="https://use.typekit.net/qoe4sik.css" rel="preload"/> <link href="https://use.typekit.net/qoe4sik.css" rel="stylesheet"/> <script type="application/ld+json"> {
#     "@context":"http://schema.org",
#     "@type":"Organization",
#     "name":"Blueground",
#     "legalName":"Blueground",
#     "url":"https://www.theblueground.com/",
#     "logo":"https://cdn.theblueground.com/website/static/img/logo-wordmark-blue-main.22765a5ac859b1b91802.svg",
#     "foundingDate":"2013",
#     "numberOfEmployees": {
#       "@type": "QuantitativeValue",
#       "description": "200-500"
#     },
#     "founder":"Alexandros Chatzieleftheriou",
#     "founders":[
#       {
#         "@type":"Person",
#         "name":"Alexandros Chatzieleftheriou"
#       },
#       {
#         "@type":"Person",
#         "name":"Alexis Maragkos"
#       },
#       {
#         "@type":"Person",
#         "name":"Andreas Nezeritis"
#       },
#       {
#         "@type":"Person",
#         "name":"Penny Papakonstantinou"
#       }
#     ],
#     "sameAs":[
#       "https://www.facebook.com/theblueground/",
#       "https://www.linkedin.com/company/blueground-co/",
#       "https://twitter.com/theblueground",
#       "https://www.instagram.com/bluegroundhomes/"
#     ]
#   } </script> <script defer="defer" src="https://maps.googleapis.com/maps/api/js?key=AIzaSyB8S1QTcW9PFbzYMTM10TgkDF6CX_qKonc&amp;language=en"></script> <script defer="defer" src="https://cdn.theblueground.com/website/static/js/runtime.3f2b1172acc81213992d.bundle.js"></script><script defer="defer" src="https://cdn.theblueground.com/website/static/js/6273.3fcecfef3572f38c36eb.bundle.js"></script><script defer="defer" src="https://cdn.theblueground.com/website/static/js/629.33c1bf7741869700327d.bundle.js"></script><script defer="defer" src="https://cdn.theblueground.com/website/static/js/4799.8fd1270f85786c568f50.bundle.js"></script><script defer="defer" src="https://cdn.theblueground.com/website/static/js/7505.c27738d65c21531757e7.bundle.js"></script><script defer="defer" src="https://cdn.theblueground.com/website/static/js/8405.069a9d4f890a69875743.bundle.js"></script><script defer="defer" src="https://cdn.theblueground.com/website/static/js/1493.899a764b53fdb3fdd84a.bundle.js"></script><script defer="defer" src="https://cdn.theblueground.com/website/static/js/9283.5309a8e848741f1d1175.bundle.js"></script><script defer="defer" src="https://cdn.theblueground.com/website/static/js/2501.0e3207ff29c884a89750.bundle.js"></script><script defer="defer" src="https://cdn.theblueground.com/website/static/js/8143.12dd4ca3b80e72c0bc82.bundle.js"></script><script defer="defer" src="https://cdn.theblueground.com/website/static/js/1497.aa58d8b7865101ab5db0.bundle.js"></script><script defer="defer" src="https://cdn.theblueground.com/website/static/js/232.63c80df5e72ac309c560.bundle.js"></script><script defer="defer" src="https://cdn.theblueground.com/website/static/js/7387.99690f84e62a071851c4.bundle.js"></script><script defer="defer" src="https://cdn.theblueground.com/website/static/js/3796.856d224fddb8199609fe.bundle.js"></script><script defer="defer" src="https://cdn.theblueground.com/website/static/js/2046.e7063284a64831079c77.bundle.js"></script><script defer="defer" src="https://cdn.theblueground.com/website/static/js/2018.6898771c51f387b9f58e.bundle.js"></script><script defer="defer" src="https://cdn.theblueground.com/website/static/js/699.7f7b2a49c65970612124.bundle.js"></script><script defer="defer" src="https://cdn.theblueground.com/website/static/js/748.0534f2ce78a169b44a74.bundle.js"></script><script defer="defer" src="https://cdn.theblueground.com/website/static/js/7836.4ec56f9a9967a0028e0f.bundle.js"></script><script defer="defer" src="https://cdn.theblueground.com/website/static/js/7039.aae8466e8d50a6ed3204.bundle.js"></script><script defer="defer" src="https://cdn.theblueground.com/website/static/js/2101.7b41c64afab36dfa8fcd.bundle.js"></script><script defer="defer" src="https://cdn.theblueground.com/website/static/js/4772.cf58034f6a9a69bf4279.bundle.js"></script><script defer="defer" src="https://cdn.theblueground.com/website/static/js/9638.7f97f5d933dd37bd37ba.bundle.js"></script><script defer="defer" src="https://cdn.theblueground.com/website/static/js/3407.3743123f5a8c0c6a1183.bundle.js"></script><script defer="defer" src="https://cdn.theblueground.com/website/static/js/property.46bb0d74d542fb26d291.bundle.js"></script><script defer="defer" src="https://cdn.theblueground.com/website/static/js/common.c4e8f9cc0f06237311b2.bundle.js"></script><link href="https://cdn.theblueground.com/website/static/css/8143.0af4d9d65363027cac8b.css" rel="stylesheet"/><link href="https://cdn.theblueground.com/website/static/css/1497.bd3c20f94fe144071e25.css" rel="stylesheet"/><link href="https://cdn.theblueground.com/website/static/css/7039.41d5df39179515ff173e.css" rel="stylesheet"/><link href="https://cdn.theblueground.com/website/static/css/2101.04b2fdeca8779bbd7078.css" rel="stylesheet"/><link href="https://cdn.theblueground.com/website/static/css/property.39388301810653c37936.css" rel="stylesheet"/><link href="https://cdn.theblueground.com/website/static/css/common.0d29a6061d5436c5e95b.css" rel="stylesheet"/></head> <body> <div id="app"> < ...
#       property: {"id":17997,"address":{"area":"Mayfair","building":"57 Green Street, London, W1K 6RH","city":"London","level2":"London","lng":-0.1545814,"lat":51.5126068},"amenities":{"apartment":[{"key":"laundryRoomUnit","price":{"charged":false},"caption":"Laundry in unit","iconUrl":"WashingMachine.svg"},{"key":"dishwasher","caption":"Dishwasher","iconUrl":"DishwashingMachine.svg"},{"key":"heating","caption":"Heating","iconUrl":"Heating.svg"},{"key":"oven","caption":"Oven","iconUrl":"Oven.svg"},{"key":"microwave","caption":"Microwave","iconUrl":"Microwave.svg"},{"key":"refrigerator","caption":"Refrigerator","iconUrl":"Refrigerator.svg"},{"key":"hairDryer","caption":"Hair dryer","iconUrl":"HairDryer.svg"},{"key":"iron","caption":"Iron","iconUrl":"Iron.svg"},{"key":"shower","caption":"Shower","iconUrl":"Shower.svg"},{"key":"appleTV","caption":"Apple TV","iconUrl":"AppleTV.svg"},{"key":"marshallSpeaker","caption":"Marshall speaker","iconUrl":"Marshall.svg"},{"key":"wideScreenTV","caption":"Wide screen TV","iconUrl":"Iptv.svg"},{"key":"nespresso","caption":"Nespresso","iconUrl":"Nespresso.svg"}],"area":[],"blueground":[{"key":"fullyEquippedKitchen","caption":"Fully equipped kitchen","iconUrl":"FullyEquippedKitchen.svg"},{"key":"linenTowels","caption":"Linen & towels","iconUrl":"Linen.svg"},{"key":"247Support","caption":"Ongoing support","iconUrl":"24_7_Support.svg"},{"key":"wifi","caption":"Wifi","iconUrl":"WiFi.svg"}],"building":[],"important":[{"key":"laundryRoomUnit","price":{"charged":false},"caption":"Laundry in unit","iconUrl":"WashingMachine.svg"},{"key":"dishwasher","caption":"Dishwasher","iconUrl":"DishwashingMachine.svg"},{"key":"heating","caption":"Heating","iconUrl":"Heating.svg"},{"key":"oven","caption":"Oven","iconUrl":"Oven.svg"},{"key":"microwave","caption":"Microwave","iconUrl":"Microwave.svg"},{"key":"refrigerator","caption":"Refrigerator","iconUrl":"Refrigerator.svg"},{"key":"hairDryer","caption":"Hair dryer","iconUrl":"HairDryer.svg"},{"key":"iron","caption":"Iron","iconUrl":"Iron.svg"},{"key":"shower","caption":"Shower","iconUrl":"Shower.svg"},{"key":"appleTV","caption":"Apple TV","iconUrl":"AppleTV.svg"},{"key":"marshallSpeaker","caption":"Marshall speaker","iconUrl":"Marshall.svg"},{"key":"wideScreenTV","caption":"Wide screen TV","iconUrl":"Iptv.svg"},{"key":"nespresso","caption":"Nespresso","iconUrl":"Nespresso.svg"}],"main":[{"key":"studio","value":"-","caption":"Studio","iconUrl":"QueenBed.svg"},{"key":"bathrooms","value":"1","caption":"Bathrooms","iconUrl":"Bathtub.svg"},{"key":"lotSizeSF","value":"391","caption":"sq. ft.","iconUrl":"LotSize.svg"},{"key":"floor","value":"-1","caption":"Floor","iconUrl":"Floor.svg"},{"key":"sleeps","value":"2","caption":"Guests","iconUrl":"Guests.svg"}],"struckthroughApartment":[{"key":"doubleGlazedWindows","caption":"Double glazed windows","iconUrl":"DoubleGlazed.svg"},{"key":"tripleGlazedWindows","caption":"Triple glazed windows","iconUrl":"DoubleGlazed.svg"},{"key":"airConditioning","caption":"Air conditioning","iconUrl":"AirConditioning.svg"},{"key":"petsAllowed","caption":"Pets allowed","iconUrl":"Pets.svg"},{"key":"bathtub","caption":"Bathtub","iconUrl":"Bathtub.svg"},{"key":"fireplace","caption":"Fireplace","iconUrl":"Fireplace.svg"},{"key":"balcony","caption":"Balcony","iconUrl":"Balcony.svg"},{"key":"pool","caption":"Pool","iconUrl":"Pool.svg"},{"key":"outdoorDining","caption":"Outdoor dining room","iconUrl":"DiningRoom.svg"},{"key":"securityAlarm","caption":"Security alarm","iconUrl":"Alarm.svg"},{"key":"securityDoor","caption":"Security door","iconUrl":"SecurityDoor.svg"}],"struckthroughBuilding":[{"key":"elevatorInTheBuilding","caption":"Elevator","iconUrl":"Elevator.svg"},{"key":"parkingSpace","caption":"Parking","iconUrl":"ParkingSlots.svg"},{"key":"gym","caption":"Gym","iconUrl":"Gym.svg"},{"key":"pool","caption":"Pool","iconUrl":"Pool.svg"},{"key":"doorman","caption":"Doorman","iconUrl":"Doorman.svg"}]},"blockReservation":false,"bookingCalendar":{"minChe ...

# %%
# split column into multiple columns by delimiter 
pd.set_option('display.max_rows', None) 
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)

df.tail(1)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 258  Blueground.pageData = {\n      property: {"id":17997,"address":{"area":"Mayfair","building":"57 Green Street, London, W1K 6RH","city":"London","level2":"London","lng":-0.1545814,"lat":51.5126068},"amenities":{"apartment":[{"key":"laundryRoomUnit","price":{"charged":false},"caption":"Laundry in unit","iconUrl":"WashingMachine.svg"},{"key":"dishwasher","caption":"Dishwasher","iconUrl":"DishwashingMachine.svg"},{"key":"heating","caption":"Heating","iconUrl":"Heating.svg"},{"key":"oven","caption":"Oven","iconUrl":"Oven.svg"},{"key":"microwave","caption":"Microwave","iconUrl":"Microwave.svg"},{"key":"refrigerator","caption":"Refrigerator","iconUrl":"Refrigerator.svg"},{"key":"hairDryer","caption":"Hair dryer","iconUrl":"HairDryer.svg"},{"key":"iron","caption":"Iron","iconUrl":"Iron.svg"},{"key":"shower","caption":"Shower","iconUrl":"Shower.svg"},{"key":"appleTV","caption":"Apple TV","iconUrl":"AppleTV.svg"},{"key":"marshallSpeaker","caption":"Marshall speaker","iconUrl":"Marshall.svg"},{"key":"wideScreenTV","caption":"Wide screen TV","iconUrl":"Iptv.svg"},{"key":"nespresso","caption":"Nespresso","iconUrl":"Nespresso.svg"}],"area":[],"blueground":[{"key":"fullyEquippedKitchen","caption":"Fully equipped kitchen","iconUrl":"FullyEquippedKitchen.svg"},{"key":"linenTowels","caption":"Linen & towels","iconUrl":"Linen.svg"},{"key":"247Support","caption":"Ongoing support","iconUrl":"24_7_Support.svg"},{"key":"wifi","caption":"Wifi","iconUrl":"WiFi.svg"}],"building":[],"important":[{"key":"laundryRoomUnit","price":{"charged":false},"caption":"Laundry in unit","iconUrl":"WashingMachine.svg"},{"key":"dishwasher","caption":"Dishwasher","iconUrl":"DishwashingMachine.svg"},{"key":"heating","caption":"Heating","iconUrl":"Heating.svg"},{"key":"oven","caption":"Oven","iconUrl":"Oven.svg"},{"key":"microwave","caption":"Microwave","iconUrl":"Microwave.svg"},{"key":"refrigerator","caption":"Refrigerator","iconUrl":"Refrigerator.svg"},{"key":"hairDryer","caption":"Hair dryer","iconUrl":"HairDryer.svg"},{"key":"iron","caption":"Iron","iconUrl":"Iron.svg"},{"key":"shower","caption":"Shower","iconUrl":"Shower.svg"},{"key":"appleTV","caption":"Apple TV","iconUrl":"AppleTV.svg"},{"key":"marshallSpeaker","caption":"Marshall speaker","iconUrl":"Marshall.svg"},{"key":"wideScreenTV","caption":"Wide screen TV","iconUrl":"Iptv.svg"},{"key":"nespresso","caption":"Nespresso","iconUrl":"Nespresso.svg"}],"main":[{"key":"studio","value":"-","caption":"Studio","iconUrl":"QueenBed.svg"},{"key":"bathrooms","value":"1","caption":"Bathrooms","iconUrl":"Bathtub.svg"},{"key":"lotSizeSF","value":"391","caption":"sq. ft.","iconUrl":"LotSize.svg"},{"key":"floor","value":"-1","caption":"Floor","iconUrl":"Floor.svg"},{"key":"sleeps","value":"2","caption":"Guests","iconUrl":"Guests.svg"}],"struckthroughApartment":[{"key":"doubleGlazedWindows","caption":"Double glazed windows","iconUrl":"DoubleGlazed.svg"},{"key":"tripleGlazedWindows","caption":"Triple glazed windows","iconUrl":"DoubleGlazed.svg"},{"key":"airConditioning","caption":"Air conditioning","iconUrl":"AirConditioning.svg"},{"key":"petsAllowed","caption":"Pets allowed","iconUrl":"Pets.svg"},{"key":"bathtub","caption":"Bathtub","iconUrl":"Bathtub.svg"},{"key":"fireplace","caption":"Fireplace","iconUrl":"Fireplace.svg"},{"key":"balcony","caption":"Balcony","iconUrl":"Balcony.svg"},{"key":"pool","caption":"Pool","iconUrl":"Pool.svg"},{"key":"outdoorDining","caption":"Outdoor dining room","iconUrl":"DiningRoom.svg"},{"key":"securityAlarm","caption":"Security alarm","iconUrl":"Alarm.svg"},{"key":"securityDoor","caption":"Security door","iconUrl":"SecurityDoor.svg"}],"struckthroughBuilding":[{"key":"elevatorInTheBuilding","caption":"Elevator","iconUrl":"Elevator.svg"},{"key":"parkingSpace","caption":"Parking","iconUrl":"ParkingSlots.svg"},{"key":"gym","caption":"Gym","iconUrl":"Gym.svg"},{"key":"pool","caption":"Pool","iconUrl":"Pool.svg"},{"key":"doorman","caption":"Doorman","iconUrl":"Doorman.svg"}]},"blockReservation":fa ...

# %%
df2 = df['details'].str.split('property', expand=True).tail(1)
df2
# Out:
#                                    0  \
# 258  Blueground.pageData = {\n
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 258  : {"id":17997,"address":{"area":"Mayfair","building":"57 Green Street, London, W1K 6RH","city":"London","level2":"London","lng":-0.1545814,"lat":51.5126068},"amenities":{"apartment":[{"key":"laundryRoomUnit","price":{"charged":false},"caption":"Laundry in unit","iconUrl":"WashingMachine.svg"},{"key":"dishwasher","caption":"Dishwasher","iconUrl":"DishwashingMachine.svg"},{"key":"heating","caption":"Heating","iconUrl":"Heating.svg"},{"key":"oven","caption":"Oven","iconUrl":"Oven.svg"},{"key":"microwave","caption":"Microwave","iconUrl":"Microwave.svg"},{"key":"refrigerator","caption":"Refrigerator","iconUrl":"Refrigerator.svg"},{"key":"hairDryer","caption":"Hair dryer","iconUrl":"HairDryer.svg"},{"key":"iron","caption":"Iron","iconUrl":"Iron.svg"},{"key":"shower","caption":"Shower","iconUrl":"Shower.svg"},{"key":"appleTV","caption":"Apple TV","iconUrl":"AppleTV.svg"},{"key":"marshallSpeaker","caption":"Marshall speaker","iconUrl":"Marshall.svg"},{"key":"wideScreenTV","caption":"Wide screen TV","iconUrl":"Iptv.svg"},{"key":"nespresso","caption":"Nespresso","iconUrl":"Nespresso.svg"}],"area":[],"blueground":[{"key":"fullyEquippedKitchen","caption":"Fully equipped kitchen","iconUrl":"FullyEquippedKitchen.svg"},{"key":"linenTowels","caption":"Linen & towels","iconUrl":"Linen.svg"},{"key":"247Support","caption":"Ongoing support","iconUrl":"24_7_Support.svg"},{"key":"wifi","caption":"Wifi","iconUrl":"WiFi.svg"}],"building":[],"important":[{"key":"laundryRoomUnit","price":{"charged":false},"caption":"Laundry in unit","iconUrl":"WashingMachine.svg"},{"key":"dishwasher","caption":"Dishwasher","iconUrl":"DishwashingMachine.svg"},{"key":"heating","caption":"Heating","iconUrl":"Heating.svg"},{"key":"oven","caption":"Oven","iconUrl":"Oven.svg"},{"key":"microwave","caption":"Microwave","iconUrl":"Microwave.svg"},{"key":"refrigerator","caption":"Refrigerator","iconUrl":"Refrigerator.svg"},{"key":"hairDryer","caption":"Hair dryer","iconUrl":"HairDryer.svg"},{"key":"iron","caption":"Iron","iconUrl":"Iron.svg"},{"key":"shower","caption":"Shower","iconUrl":"Shower.svg"},{"key":"appleTV","caption":"Apple TV","iconUrl":"AppleTV.svg"},{"key":"marshallSpeaker","caption":"Marshall speaker","iconUrl":"Marshall.svg"},{"key":"wideScreenTV","caption":"Wide screen TV","iconUrl":"Iptv.svg"},{"key":"nespresso","caption":"Nespresso","iconUrl":"Nespresso.svg"}],"main":[{"key":"studio","value":"-","caption":"Studio","iconUrl":"QueenBed.svg"},{"key":"bathrooms","value":"1","caption":"Bathrooms","iconUrl":"Bathtub.svg"},{"key":"lotSizeSF","value":"391","caption":"sq. ft.","iconUrl":"LotSize.svg"},{"key":"floor","value":"-1","caption":"Floor","iconUrl":"Floor.svg"},{"key":"sleeps","value":"2","caption":"Guests","iconUrl":"Guests.svg"}],"struckthroughApartment":[{"key":"doubleGlazedWindows","caption":"Double glazed windows","iconUrl":"DoubleGlazed.svg"},{"key":"tripleGlazedWindows","caption":"Triple glazed windows","iconUrl":"DoubleGlazed.svg"},{"key":"airConditioning","caption":"Air conditioning","iconUrl":"AirConditioning.svg"},{"key":"petsAllowed","caption":"Pets allowed","iconUrl":"Pets.svg"},{"key":"bathtub","caption":"Bathtub","iconUrl":"Bathtub.svg"},{"key":"fireplace","caption":"Fireplace","iconUrl":"Fireplace.svg"},{"key":"balcony","caption":"Balcony","iconUrl":"Balcony.svg"},{"key":"pool","caption":"Pool","iconUrl":"Pool.svg"},{"key":"outdoorDining","caption":"Outdoor dining room","iconUrl":"DiningRoom.svg"},{"key":"securityAlarm","caption":"Security alarm","iconUrl":"Alarm.svg"},{"key":"securityDoor","caption":"Security door","iconUrl":"SecurityDoor.svg"}],"struckthroughBuilding":[{"key":"elevatorInTheBuilding","caption":"Elevator","iconUrl":"Elevator.svg"},{"key":"parkingSpace","caption":"Parking","iconUrl":"ParkingSlots.svg"},{"key":"gym","caption":"Gym","iconUrl":"Gym.svg"},{"key":"pool","caption":"Pool","iconUrl":"Pool.svg"},{"key":"doorman","caption":"Doorman","iconUrl":"Doorman.svg"}]},"blockReservation":false,"bookingCalendar":{"minCheckIn":"20 ...
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 258  . And, thanks to our superior quality mattresses, luxury linens, and\n  towels, you can relax knowing you’ll always feel comfortably at home. When you’re ready for some fun, you can take in\n  the London vibes or bring the entertainment to you with the premium wireless speaker or smart\n  TV.  This apartment also offers in-apartment laundry.</p>\n","amenities":"\n","interaction":"<p><b>Arrival and ongoing support</b></p>\n<p>The entire apartment is yours to enjoy! You’ll either be personally greeted by a Blueground team member or given self\n  check-in instructions.</p>\n<p>Throughout your stay, you’ll have access to our Client Experience team through the Blueground App.\n  You can schedule additional cleanings, submit maintenance requests, and view our neighborhood recommendations with\n  just a few taps.</p>\n<p>We’ll share all details upon confirmation of your stay.</p>\n","location":"<p><b>Ideally Located</b></p>\n<p>This furnished flat is in Mayfair, one of London's most iconic luxurious neighbourhoods, located between Oxford Circus, Marble Arch and Green Park, right in the heart of the city. Mayfair has stunning Georgian architecture all-round and is complemented by elegant squares. The area offers many top-rated primary and secondary schools and houses, and several campuses of the University of Westminster. Alongside Savile Row, the street famous for bespoke tailoring, are some of the city’s oldest retail brands, flagship outlets and department stores such as Selfridges on Oxford Street and Liberty on Regent Street. There are many up-market Michelin-starred restaurants and casual pubs to enjoy, as well as leading art galleries. Bond Street is the nearest tube station, which connects easily to Canary Wharf and the City of London.</p>\n"},"displayArea":"Mayfair, London","hasJuniorBedroom":false,"heating":[{"type":"CENTRAL_HEATING","managedBy":"APARTMENT"}],"localDay":"2022-09-26","metaImage":"https://photos2.theblueground.com/736/pg17997-o-d1edee23-f052-cd77-60f0-611bf3263402.jpg","minimumStayMonths":1,"name":"Green St","parkingSpot":null,"path":"furnished-apartments-london-uk/london-mayfair-094","photos":[{"url":"https://photos2.theblueground.com/736/pg17997-o-d1edee23-f052-cd77-60f0-611bf3263402.jpg","caption":"Lounge Area","tags":["furnished","livingRoom"],"primary":true},{"url":"https://photos2.theblueground.com/736/pg17997-o-ad7d3703-0a00-4e69-4faa-0367f7f45c90.jpg","caption":"Lounge Area","tags":["furnished","livingRoom"],"primary":false},{"url":"https://photos2.theblueground.com/736/pg17997-o-4773e331-4a31-73e6-6c92-17c3aa496a5e.jpg","caption":"Lounge Area","tags":["furnished","livingRoom"],"primary":false},{"url":"https://photos2.theblueground.com/736/pg17997-o-5556684b-d47d-5941-e5eb-01f29634380f.jpg","caption":"Office Area","tags":["furnished","livingRoom"],"primary":false},{"url":"https://photos2.theblueground.com/736/pg17997-o-4f88a416-fbec-7b6c-6335-bd0183785a82.jpg","caption":" Dining Area","tags":["furnished","livingRoom"],"primary":false},{"url":"https://photos2.theblueground.com/736/pg17997-o-2ca2ace6-9c67-d1a4-c9bd-d5eecec6ce91.jpg","caption":"Fully Equipped Kitchen ","tags":["furnished","kitchen"],"primary":false},{"url":"https://photos2.theblueground.com/736/pg17997-o-7c225ff3-85a2-d9d8-26a2-706c0a6179fb.jpg","caption":"Fully Equipped Kitchen ","tags":["furnished","kitchen"],"primary":false},{"url":"https://photos2.theblueground.com/736/pg17997-o-fce5364f-4ef7-2200-cd9c-6d2d4437ae87.jpg","caption":"Washer in apartment","tags":["furnished","rest"],"primary":false},{"url":"https://photos2.theblueground.com/736/pg17997-o-e93f5333-c2c1-616f-db60-1d79443005c6.jpg","caption":"Queen Size Bed","tags":["furnished","livingRoom"],"primary":false},{"url":"https://photos2.theblueground.com/736/pg17997-o-8ed52357-733a-a156-fc20-c3e00bb1c7b3.jpg","caption":"Queen Size Bed","tags":["furnished","livingRoom"],"primary":false},{"url":"https://photos2.theblueground.com/736/pg17997-o-98bc76d1-4b8f-009d-b970-5d315f2fbb ...
#
#                                                                                                                                                                                                                                3
# 258  PhotoSource":"OWN_PROPERTY","rules":{"smokingAllowed":false,"eventsAllowed":true,"petsAllowed":false},"sleepingArrangements":["QUEEN"],"thingsToKnow":[],"videoTourUrl":null,"virtualTourUrl":null,"amenitiesConfig":[]} };

# %%
df3 = df2[1].str.split('{', expand=True).tail(1)

# %%
dic = df3.to_dict('index')
dic
# Out:
# {258: {0: ': ',
#   1: '"id":17997,"address":',
#   2: '"area":"Mayfair","building":"57 Green Street, London, W1K 6RH","city":"London","level2":"London","lng":-0.1545814,"lat":51.5126068},"amenities":',
#   3: '"apartment":[',
#   4: '"key":"laundryRoomUnit","price":',
#   5: '"charged":false},"caption":"Laundry in unit","iconUrl":"WashingMachine.svg"},',
#   6: '"key":"dishwasher","caption":"Dishwasher","iconUrl":"DishwashingMachine.svg"},',
#   7: '"key":"heating","caption":"Heating","iconUrl":"Heating.svg"},',
#   8: '"key":"oven","caption":"Oven","iconUrl":"Oven.svg"},',
#   9: '"key":"microwave","caption":"Microwave","iconUrl":"Microwave.svg"},',
#   10: '"key":"refrigerator","caption":"Refrigerator","iconUrl":"Refrigerator.svg"},',
#   11: '"key":"hairDryer","caption":"Hair dryer","iconUrl":"HairDryer.svg"},',
#   12: '"key":"iron","caption":"Iron","iconUrl":"Iron.svg"},',
#   13: '"key":"shower","caption":"Shower","iconUrl":"Shower.svg"},',
#   14: '"key":"appleTV","caption":"Apple TV","iconUrl":"AppleTV.svg"},',
#   15: '"key":"marshallSpeaker","caption":"Marshall speaker","iconUrl":"Marshall.svg"},',
#   16: '"key":"wideScreenTV","caption":"Wide screen TV","iconUrl":"Iptv.svg"},',
#   17: '"key":"nespresso","caption":"Nespresso","iconUrl":"Nespresso.svg"}],"area":[],"blueground":[',
#   18: '"key":"fullyEquippedKitchen","caption":"Fully equipped kitchen","iconUrl":"FullyEquippedKitchen.svg"},',
#   19: '"key":"linenTowels","caption":"Linen & towels","iconUrl":"Linen.svg"},',
#   20: '"key":"247Support","caption":"Ongoing support","iconUrl":"24_7_Support.svg"},',
#   21: '"key":"wifi","caption":"Wifi","iconUrl":"WiFi.svg"}],"building":[],"important":[',
#   22: '"key":"laundryRoomUnit","price":',
#   23: '"charged":false},"caption":"Laundry in unit","iconUrl":"WashingMachine.svg"},',
#   24: '"key":"dishwasher","caption":"Dishwasher","iconUrl":"DishwashingMachine.svg"},',
#   25: '"key":"heating","caption":"Heating","iconUrl":"Heating.svg"},',
#   26: '"key":"oven","caption":"Oven","iconUrl":"Oven.svg"},',
#   27: '"key":"microwave","caption":"Microwave","iconUrl":"Microwave.svg"},',
#   28: '"key":"refrigerator","caption":"Refrigerator","iconUrl":"Refrigerator.svg"},',
#   29: '"key":"hairDryer","caption":"Hair dryer","iconUrl":"HairDryer.svg"},',
#   30: '"key":"iron","caption":"Iron","iconUrl":"Iron.svg"},',
#   31: '"key":"shower","caption":"Shower","iconUrl":"Shower.svg"},',
#   32: '"key":"appleTV","caption":"Apple TV","iconUrl":"AppleTV.svg"},',
#   33: '"key":"marshallSpeaker","caption":"Marshall speaker","iconUrl":"Marshall.svg"},',
#   34: '"key":"wideScreenTV","caption":"Wide screen TV","iconUrl":"Iptv.svg"},',
#   35: '"key":"nespresso","caption":"Nespresso","iconUrl":"Nespresso.svg"}],"main":[',
#   36: '"key":"studio","value":"-","caption":"Studio","iconUrl":"QueenBed.svg"},',
#   37: '"key":"bathrooms","value":"1","caption":"Bathrooms","iconUrl":"Bathtub.svg"},',
#   38: '"key":"lotSizeSF","value":"391","caption":"sq. ft.","iconUrl":"LotSize.svg"},',
#   39: '"key":"floor","value":"-1","caption":"Floor","iconUrl":"Floor.svg"},',
#   40: '"key":"sleeps","value":"2","caption":"Guests","iconUrl":"Guests.svg"}],"struckthroughApartment":[',
#   41: '"key":"doubleGlazedWindows","caption":"Double glazed windows","iconUrl":"DoubleGlazed.svg"},',
#   42: '"key":"tripleGlazedWindows","caption":"Triple glazed windows","iconUrl":"DoubleGlazed.svg"},',
#   43: '"key":"airConditioning","caption":"Air conditioning","iconUrl":"AirConditioning.svg"},',
#   44: '"key":"petsAllowed","caption":"Pets allowed","iconUrl":"Pets.svg"},',
#   45: '"key":"bathtub","caption":"Bathtub","iconUrl":"Bathtub.svg"},',
#   46: '"key":"fireplace","caption":"Fireplace","iconUrl":"Fireplace.svg"},',
#   47: '"key":"balcony","caption":"Balcony","iconUrl":"Balcony.svg"},',
#   48: '"key":"pool","caption":"Pool","iconUrl":"Pool.svg"},',
#   49: '"key":"outdoorDining","caption":"Outdoor dining room","iconUrl":"DiningRoom.svg"},',
#   50: '"key":"securityAlarm","caption":"Security alarm","iconUrl":"Alarm.svg"},',
#   51: '"key":"securityDoor","caption":"Security door","iconUrl":"SecurityDoor.svg"}],"struckthroughBuilding":[',
#   52: '"key":"elevatorInTheBuilding","caption":"Elevator","iconUrl":"Elevator.svg"},',
#   53: '"key":"parkingSpace","caption":"Parking","iconUrl":"ParkingSlots.svg"},',
#   54: '"key":"gym","caption":"Gym","iconUrl":"Gym.svg"},',
#   55: '"key":"pool","caption":"Pool","iconUrl":"Pool.svg"},',
#   56: '"key":"doorman","caption":"Doorman","iconUrl":"Doorman.svg"}]},"blockReservation":false,"bookingCalendar":',
#   57: '"minCheckIn":"2023-06-01","maxCheckIn":"2023-06-16","options":[',
#   58: '"checkIn":"2023-06-01","minCheckOut":"2023-06-30","minStayInDays":29,"maxCheckOut":null},',
#   59: '"checkIn":"2023-06-02","minCheckOut":"2023-07-01","minStayInDays":29,"maxCheckOut":null},',
#   60: '"checkIn":"2023-06-03","minCheckOut":"2023-07-02","minStayInDays":29,"maxCheckOut":null},',
#   61: '"checkIn":"2023-06-04","minCheckOut":"2023-07-03","minStayInDays":29,"maxCheckOut":null},',
#   62: '"checkIn":"2023-06-05","minCheckOut":"2023-07-04","minStayInDays":29,"maxCheckOut":null},',
#   63: '"checkIn":"2023-06-06","minCheckOut":"2023-07-05","minStayInDays":29,"maxCheckOut":null},',
#   64: '"checkIn":"2023-06-07","minCheckOut":"2023-07-06","minStayInDays":29,"maxCheckOut":null},',
#   65: '"checkIn":"2023-06-08","minCheckOut":"2023-07-07","minStayInDays":29,"maxCheckOut":null},',
#   66: '"checkIn":"2023-06-09","minCheckOut":"2023-07-08","minStayInDays":29,"maxCheckOut":null},',
#   67: '"checkIn":"2023-06-10","minCheckOut":"2023-07-09","minStayInDays":29,"maxCheckOut":null},',
#   68: '"checkIn":"2023-06-11","minCheckOut":"2023-07-10","minStayInDays":29,"maxCheckOut":null},',
#   69: '"checkIn":"2023-06-12","minCheckOut":"2023-07-11","minStayInDays":29,"maxCheckOut":null},',
#   70: '"checkIn":"2023-06-13","minCheckOut":"2023-07-12","minStayInDays":29,"maxCheckOut":null},',
#   71: '"checkIn":"2023-06-14","minCheckOut":"2023-07-13","minStayInDays":29,"maxCheckOut":null},',
#   72: '"checkIn":"2023-06-15","minCheckOut":"2023-07-14","minStayInDays":29,"maxCheckOut":null},',
#   73: '"checkIn":"2023-06-16","minCheckOut":"2023-07-15","minStayInDays":29,"maxCheckOut":null}]},"cityCode":"LON","code":"94","cooling":[],"countryCode":"GBR","description":',
#   74: '"intro":"<p>\\n  Feel at home wherever you choose to live with Blueground. You’ll love this charming Mayfair furnished\\n  studio apartment with its modern decor, fully equipped kitchen, and sophisticated living room\\n    .\\n  Ideally located, you’re close to all the best that London has to offer!\\n</p>\\n","space":"<p><b>Designed with you in mind</b></p>\\n<p>As with any Blueground apartment, you’ll find a thoughtfully designed space complete with beautiful furniture and a\\n  fully-equipped kitchen in this studio '}}

# %%
dic.values()
# Out:
# dict_values([{0: ': ', 1: '"id":17997,"address":', 2: '"area":"Mayfair","building":"57 Green Street, London, W1K 6RH","city":"London","level2":"London","lng":-0.1545814,"lat":51.5126068},"amenities":', 3: '"apartment":[', 4: '"key":"laundryRoomUnit","price":', 5: '"charged":false},"caption":"Laundry in unit","iconUrl":"WashingMachine.svg"},', 6: '"key":"dishwasher","caption":"Dishwasher","iconUrl":"DishwashingMachine.svg"},', 7: '"key":"heating","caption":"Heating","iconUrl":"Heating.svg"},', 8: '"key":"oven","caption":"Oven","iconUrl":"Oven.svg"},', 9: '"key":"microwave","caption":"Microwave","iconUrl":"Microwave.svg"},', 10: '"key":"refrigerator","caption":"Refrigerator","iconUrl":"Refrigerator.svg"},', 11: '"key":"hairDryer","caption":"Hair dryer","iconUrl":"HairDryer.svg"},', 12: '"key":"iron","caption":"Iron","iconUrl":"Iron.svg"},', 13: '"key":"shower","caption":"Shower","iconUrl":"Shower.svg"},', 14: '"key":"appleTV","caption":"Apple TV","iconUrl":"AppleTV.svg"},', 15: '"key":"marshallSpeaker","caption":"Marshall speaker","iconUrl":"Marshall.svg"},', 16: '"key":"wideScreenTV","caption":"Wide screen TV","iconUrl":"Iptv.svg"},', 17: '"key":"nespresso","caption":"Nespresso","iconUrl":"Nespresso.svg"}],"area":[],"blueground":[', 18: '"key":"fullyEquippedKitchen","caption":"Fully equipped kitchen","iconUrl":"FullyEquippedKitchen.svg"},', 19: '"key":"linenTowels","caption":"Linen & towels","iconUrl":"Linen.svg"},', 20: '"key":"247Support","caption":"Ongoing support","iconUrl":"24_7_Support.svg"},', 21: '"key":"wifi","caption":"Wifi","iconUrl":"WiFi.svg"}],"building":[],"important":[', 22: '"key":"laundryRoomUnit","price":', 23: '"charged":false},"caption":"Laundry in unit","iconUrl":"WashingMachine.svg"},', 24: '"key":"dishwasher","caption":"Dishwasher","iconUrl":"DishwashingMachine.svg"},', 25: '"key":"heating","caption":"Heating","iconUrl":"Heating.svg"},', 26: '"key":"oven","caption":"Oven","iconUrl":"Oven.svg"},', 27: '"key":"microwave","caption":"Microwave","iconUrl":"Microwave.svg"},', 28: '"key":"refrigerator","caption":"Refrigerator","iconUrl":"Refrigerator.svg"},', 29: '"key":"hairDryer","caption":"Hair dryer","iconUrl":"HairDryer.svg"},', 30: '"key":"iron","caption":"Iron","iconUrl":"Iron.svg"},', 31: '"key":"shower","caption":"Shower","iconUrl":"Shower.svg"},', 32: '"key":"appleTV","caption":"Apple TV","iconUrl":"AppleTV.svg"},', 33: '"key":"marshallSpeaker","caption":"Marshall speaker","iconUrl":"Marshall.svg"},', 34: '"key":"wideScreenTV","caption":"Wide screen TV","iconUrl":"Iptv.svg"},', 35: '"key":"nespresso","caption":"Nespresso","iconUrl":"Nespresso.svg"}],"main":[', 36: '"key":"studio","value":"-","caption":"Studio","iconUrl":"QueenBed.svg"},', 37: '"key":"bathrooms","value":"1","caption":"Bathrooms","iconUrl":"Bathtub.svg"},', 38: '"key":"lotSizeSF","value":"391","caption":"sq. ft.","iconUrl":"LotSize.svg"},', 39: '"key":"floor","value":"-1","caption":"Floor","iconUrl":"Floor.svg"},', 40: '"key":"sleeps","value":"2","caption":"Guests","iconUrl":"Guests.svg"}],"struckthroughApartment":[', 41: '"key":"doubleGlazedWindows","caption":"Double glazed windows","iconUrl":"DoubleGlazed.svg"},', 42: '"key":"tripleGlazedWindows","caption":"Triple glazed windows","iconUrl":"DoubleGlazed.svg"},', 43: '"key":"airConditioning","caption":"Air conditioning","iconUrl":"AirConditioning.svg"},', 44: '"key":"petsAllowed","caption":"Pets allowed","iconUrl":"Pets.svg"},', 45: '"key":"bathtub","caption":"Bathtub","iconUrl":"Bathtub.svg"},', 46: '"key":"fireplace","caption":"Fireplace","iconUrl":"Fireplace.svg"},', 47: '"key":"balcony","caption":"Balcony","iconUrl":"Balcony.svg"},', 48: '"key":"pool","caption":"Pool","iconUrl":"Pool.svg"},', 49: '"key":"outdoorDining","caption":"Outdoor dining room","iconUrl":"DiningRoom.svg"},', 50: '"key":"securityAlarm","caption":"Security alarm","iconUrl":"Alarm.svg"},', 51: '"key":"securityDoor","caption":"Security door","iconUrl":"SecurityDoor.svg"}],"struckthroughBuilding":[', 52: '"key":"e ...

# %%
dic.get('lotSizeSF')
