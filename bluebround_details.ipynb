# %% [markdown]
# Import Libraries

# %%
import time
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import numpy as np

# %% [markdown]
# Insert WebLink

# %% [markdown]
# /furnished-apartments-london-uk/london-croydon-202
#
# /furnished-apartments-london-uk/london-bayswater-046
#
# /furnished-apartments-london-uk/london-whitechapel-brick-lane-145

# %%
weblink = 'https://www.theblueground.com'
pagesite = '/furnished-apartments-london-uk/london-whitechapel-brick-lane-145'
page = requests.get(weblink + pagesite)
html = page.content

print(weblink + pagesite)

# %% [markdown]
# Start BeautifulSoup

# %%
# parse the html and save it into a BeautifulSoup instance
bs = BeautifulSoup(html, 'html.parser')
soup = BeautifulSoup(html, 'html.parser')

# %%
print(bs.prettify())

# %% [markdown]
# Here are some simple ways to navigate that data structure:

# %%
soup.title

# %%
soup.title.name

# %%
soup.title.string

# %%
soup.title.parent.name

# %%
soup.p

# %%
soup.a

# %%
soup.find_all('a')

# %%
soup.find(id="link3")

# %%
soup.find_all('span')

# %%
soup.find_all('div')

# %%
soup.find_all('div', class_='bg-wrapper bg-container-fluid lt-gutter--top-inline lt-gutter--bottom')

# %%
title = soup.find("meta", property="og:title")
url = soup.find("meta", property="og:url")

print(title["content"] if title else "No meta title given")
print(url["content"] if url else "No meta url given")

# %%
# import libraries
import urllib.request
from bs4 import BeautifulSoup
# specify the url
urlpage = 'https://www.theblueground.com/furnished-apartments-london-uk/london-whitechapel-brick-lane-145' 
print(urlpage)
# query the website and return the html to the variable 'page'
page = urllib.request.urlopen(urlpage)
# parse the html using beautiful soup and store in variable 'soup'
soup = BeautifulSoup(page, 'html.parser')
# find product items
# at time of publication, Nov 2018:
# results = soup.find_all('div', attrs={'class': 'listing category_templates clearfix productListing'})
# updated Nov 2019:
results = soup.find_all('div', attrs={'class': 'property__amenities-list-item'})
print('Number of results', len(results))

# %%
from bs4 import BeautifulSoup
import requests
 
resp = requests.get('https://www.theblueground.com/furnished-apartments-london-uk/london-whitechapel-brick-lane-145')
 
html = resp.content
soup = BeautifulSoup(html)
 
option_tags = soup.find_all("script")
option_tags

# %%
soup = BeautifulSoup(html, features="html.parser")
test = soup.findAll('script')
blah = [x.strip() for x in test[0].string.split('\n') if x.strip()]
blah

# %%
soup = BeautifulSoup(html, features="html.parser")
test = soup.findAllNext('script')
blah = [x.strip() for x in test[0].text.split('\n') if x.strip()]
blah
test

# %%
blah = soup.findAllNext('script')
blah2 = [x.strip() for x in test[0].string.split('\n') if x.strip()]
blah2

# %%
# import libraries
import urllib.request
from bs4 import BeautifulSoup
# specify the url
urlpage = 'https://www.theblueground.com/furnished-apartments-london-uk/london-bayswater-046' 
print(urlpage)
# query the website and return the html to the variable 'page'
page = urllib.request.urlopen(urlpage)
# parse the html using beautiful soup and store in variable 'soup'
soup = BeautifulSoup(page, 'html.parser')
# find product items
# at time of publication, Nov 2018:
# results = soup.find_all('div', attrs={'class': 'listing category_templates clearfix productListing'})
# updated Nov 2019:
results = soup.find_all('div', attrs={'span': 'property__amenities-list-item'})
print('Number of results', len(results))

# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

#page = 'https://www.theblueground.com/furnished-apartments-london-uk/london-hammersmith-205' 
# page = 'https://www.theblueground.com/furnished-apartments-london-uk/london-whitechapel-brick-lane-079'

# studio:
page = 'https://www.theblueground.com/furnished-apartments-london-uk/london-clerkenwell-115'

website = requests.get(page)
results = BeautifulSoup(website.content, 'html.parser')

blogbeitraege = results.findAll('div', class_='property__amenities-list-item')
blogbeitraege = results.findAll()

blogbeitraege_lst = (blogbeitrag.get_text() for blogbeitrag in blogbeitraege)
blogbeitraege_lst = [blogbeitrag.strip() for blogbeitrag in blogbeitraege_lst]

df = pd.DataFrame(blogbeitraege_lst, columns=['details'])

# %%
results
# Out:
# <!DOCTYPE html>
#  <html lang="en"> <head> <meta charset="utf-8"/> <meta content="IE=edge, chrome=1" http-equiv="X-UA-Compatible"/> <meta content="noindex" name="robots"/> <script>  var dataLayer = [{
#       country: 'GBR',
#       city: 'LON',
#       pageType: 'propertyDetails',
#       propertyId: '18766',
#       propertyCode:'LON-115',
#       neighborhood: 'Clerkenwell',
# ...

# %%
# split column into multiple columns by delimiter 
pd.set_option('display.max_rows', None) 
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)

df.tail(1)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
df2 = df['details'].str.split('property:', expand=True).tail(1)
df2
# Out:
#                                    0  \
# 258  Blueground.pageData = {\n
#
# ...

# %% [markdown]
# lotSizeSF

# %%
test = df2[1].str.split('258:', expand=True)
test
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
t = str(df2[1].values[0])
print(type(t))
print(t)
# Out:
# <class 'str'>
# ...

# %%
t = t.strip()
t = t.rstrip(';')
t = t.strip()
t
# Out:
# '{"id":18766,"address":{"area":"Clerkenwell","building":"65 Farringdon Road, London, EC1M 3JB","city":"London","level2":"London","lng":-0.1063344,"lat":51.520821},"amenities":{"apartment":[{"key":"cityView","caption":"City view","iconUrl":"CityView.svg"},{"key":"laundryRoomUnit","price":{"charged":false},"caption":"Laundry in unit","iconUrl":"WashingMachine.svg"},{"key":"heating","caption":"Heating","iconUrl":"Heating.svg"},{"key":"petsAllowed","caption":"Pets allowed","iconUrl":"Pets.svg"},{"key":"oven","caption":"Oven","iconUrl":"Oven.svg"},{"key":"microwave","caption":"Microwave","iconUrl":"Microwave.svg"},{"key":"refrigerator","caption":"Refrigerator","iconUrl":"Refrigerator.svg"},{"key":"hairDryer","caption":"Hair dryer","iconUrl":"HairDryer.svg"},{"key":"iron","caption":"Iron","iconUrl":"Iron.svg"},{"key":"shower","caption":"Shower","iconUrl":"Shower.svg"},{"key":"balcony","caption":"Balcony","iconUrl":"Balcony.svg"},{"key":"marshallSpeaker","caption":"Marshall speaker","iconUr
# ...

# %%
t = t.strip()
t = t.rstrip('}')
t = t.strip()
t
# Out:
# '{"id":18766,"address":{"area":"Clerkenwell","building":"65 Farringdon Road, London, EC1M 3JB","city":"London","level2":"London","lng":-0.1063344,"lat":51.520821},"amenities":{"apartment":[{"key":"cityView","caption":"City view","iconUrl":"CityView.svg"},{"key":"laundryRoomUnit","price":{"charged":false},"caption":"Laundry in unit","iconUrl":"WashingMachine.svg"},{"key":"heating","caption":"Heating","iconUrl":"Heating.svg"},{"key":"petsAllowed","caption":"Pets allowed","iconUrl":"Pets.svg"},{"key":"oven","caption":"Oven","iconUrl":"Oven.svg"},{"key":"microwave","caption":"Microwave","iconUrl":"Microwave.svg"},{"key":"refrigerator","caption":"Refrigerator","iconUrl":"Refrigerator.svg"},{"key":"hairDryer","caption":"Hair dryer","iconUrl":"HairDryer.svg"},{"key":"iron","caption":"Iron","iconUrl":"Iron.svg"},{"key":"shower","caption":"Shower","iconUrl":"Shower.svg"},{"key":"balcony","caption":"Balcony","iconUrl":"Balcony.svg"},{"key":"marshallSpeaker","caption":"Marshall speaker","iconUr
# ...

# %%
# https://jsonformatter.org/json-viewer
import json

# %%
person_dict = json.loads(t)
print(type(person_dict))
person_dict
# Out:
# <class 'dict'>
# {'id': 18766,
#  'address': {'area': 'Clerkenwell',
#   'building': '65 Farringdon Road, London, EC1M 3JB',
#   'city': 'London',
#   'level2': 'London',
#   'lng': -0.1063344,
#   'lat': 51.520821},
#  'amenities': {'apartment': [{'key': 'cityView',
#     'caption': 'City view',
#     'iconUrl': 'CityView.svg'},
#    {'key': 'laundryRoomUnit',
#     'price': {'charged': False},
#     'caption': 'Laundry in unit',
#     'iconUrl': 'WashingMachine.svg'},
#    {'key': 'heating', 'caption': 'Heating', 'iconUrl': 'Heating.svg'},
#    {'key': 'petsAllowed', 'caption': 'Pets allowed', 'iconUrl': 'Pets.svg'},
#    {'key': 'oven', 'caption': 'Oven', 'iconUrl': 'Oven.svg'},
#    {'key': 'microwave', 'caption': 'Microwave', 'iconUrl': 'Microwave.svg'},
#    {'key': 'refrigerator',
#     'caption': 'Refrigerator',
#     'iconUrl': 'Refrigerator.svg'},
#    {'key': 'hairDryer', 'caption': 'Hair dryer', 'iconUrl': 'HairDryer.svg'},
# ...

# %%
y = json.dumps(person_dict, indent=4, sort_keys=True)
print(type(y))
print(y)
# Out:
# <class 'str'>
# {
#     "address": {
#         "area": "Clerkenwell",
#         "building": "65 Farringdon Road, London, EC1M 3JB",
#         "city": "London",
#         "lat": 51.520821,
#         "level2": "London",
#         "lng": -0.1063344
#     },
#     "amenities": {
#         "apartment": [
#             {
#                 "caption": "City view",
#                 "iconUrl": "CityView.svg",
#                 "key": "cityView"
#             },
#             {
#                 "caption": "Laundry in unit",
#                 "iconUrl": "WashingMachine.svg",
#                 "key": "laundryRoomUnit",
#                 "price": {
#                     "charged": false
#                 }
#             },
#             {
#                 "caption": "Heating",
#                 "iconUrl": "Heating.svg",
#                 "key": "heating"
#             },
#             {
#                 "caption": "Pets allowed",
#                 "iconUrl": "Pets.svg",
# ...

# %%
for keys, values in person_dict.items():
    print(keys + ':', values)
# Out:
# id: 18766
# address: {'area': 'Clerkenwell', 'building': '65 Farringdon Road, London, EC1M 3JB', 'city': 'London', 'level2': 'London', 'lng': -0.1063344, 'lat': 51.520821}
# ...

# %% [markdown]
# # Print values in base
# print("This is in base:", weather_hh['base'])
#
# # Print values in main
# print("This is in main:", weather_hh['main'])
#
# # Print values in temp
# print("This is the Temp in main:", weather_hh['main']['temp'])

# %%
print("This is the id:", person_dict['id'])
# Out:
# This is the id: 18766

# %%
print("This is the address :", person_dict['address'])
# Out:
# This is the address : {'area': 'Clerkenwell', 'building': '65 Farringdon Road, London, EC1M 3JB', 'city': 'London', 'level2': 'London', 'lng': -0.1063344, 'lat': 51.520821}

# %%
print("This is the long  :", person_dict['address']['lng'])
print("This is the lat  :", person_dict['address']['lat'])
# Out:
# This is the long  : -0.1063344
# This is the lat  : 51.520821

# %%
person_dict_normalized = pd.json_normalize(person_dict, sep='_')
display(person_dict_normalized)
# Out:
#       id  blockReservation cityCode code cooling countryCode  \
# 0  18766             False      LON  115      []         GBR
#
#            displayArea  hasJuniorBedroom  \
# 0  Clerkenwell, London             False
#
#                                                    heating    localDay  \
# 0  [{'type': 'CENTRAL_HEATING', 'managedBy': 'APARTMENT'}]  2022-09-28
#
#                                                                                   metaImage  \
# 0  https://photos2.theblueground.com/736/pg18766-o-5994ee18-49da-bae2-3a3b-385f15cccef6.jpg
#
#    minimumStayMonths           name parkingSpot  \
# 0                  1  Farringdon Rd        None
#
#                                                     path  \
# 0  furnished-apartments-london-uk/london-clerkenwell-115
#
# ...

# %%
x = person_dict_normalized['amenities_main'].values[0]
print(type(x))
print(x)
# Out:
# <class 'list'>
# [{'key': 'studio', 'value': '-', 'caption': 'Studio', 'iconUrl': 'QueenBed.svg'}, {'key': 'bathrooms', 'value': '1', 'caption': 'Bathrooms', 'iconUrl': 'Bathtub.svg'}, {'key': 'lotSizeSF', 'value': '577', 'caption': 'sq. ft.', 'iconUrl': 'LotSize.svg'}, {'key': 'cityView', 'caption': 'City view', 'iconUrl': 'CityView.svg'}, {'key': 'floor', 'value': '4', 'caption': 'Floor', 'iconUrl': 'Floor.svg'}, {'key': 'balcony', 'caption': 'Balcony', 'iconUrl': 'Balcony.svg'}]

# %%
x = person_dict_normalized['amenities_main'].values[0]
print(type(x))
print(type(x[2]))
print(x[2]['key'])
print(x[2]['value'])
print(x[2]['caption'])
# Out:
# <class 'list'>
# <class 'dict'>
# lotSizeSF
# 577
# sq. ft.

# %% [markdown]
# lotSizeSF
# 589
