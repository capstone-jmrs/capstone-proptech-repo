# %%
import time
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import pandas as pd
from datetime import datetime
import math 

from sql_functions import *    

import psycopg2   

import sql_functions as sf
import sqlalchemy

# %%
schema = 'capstone_jmrs'

# %%
sql = (f"""
SELECT * 
FROM {schema}.rightmove_1"""
)

# %%
rm = get_dataframe(sql)
# Out:
#              platform_id   platform           neighbourhood prices_pcm  \
# 0     property-127236689  Rightmove  Hammersmith and Fulham       3683
# 1     property-127366049  Rightmove  Hammersmith and Fulham       3750
# 2     property-127365830  Rightmove  Hammersmith and Fulham       2600
# 3     property-126019895  Rightmove  Hammersmith and Fulham       1350
# 4     property-127361573  Rightmove  Hammersmith and Fulham       1750
# ...                  ...        ...                     ...        ...
# 9720  property-124925873  Rightmove               Islington       2817
# 9721   property-84868017  Rightmove               Islington       5750
# 9722   property-79835193  Rightmove               Islington       3792
# 9723   property-65417791  Rightmove               Islington       1582
# 9724  property-127368341  Rightmove               Islington       1647
#
#           furniture scraping_date
# 0         furnished    2022-09-23
# 1         furnished    2022-09-23
# 2         furnished    2022-09-23
# 3         furnished    2022-09-23
# 4         furnished    2022-09-23
# ...             ...           ...
# 9720  partFurnished    2022-09-23
# 9721  partFurnished    2022-09-23
# 9722  partFurnished    2022-09-23
# 9723  partFurnished    2022-09-23
# 9724  partFurnished    2022-09-23
#
# [9725 rows x 6 columns]

# %%
# format the ID column
rm['platform_id'] = rm['platform_id'].str.removeprefix('property-')#.astype(int)
rm
# Out:
#      platform_id   platform           neighbourhood prices_pcm      furniture  \
# 0      127236689  Rightmove  Hammersmith and Fulham       3683      furnished
# 1      127366049  Rightmove  Hammersmith and Fulham       3750      furnished
# 2      127365830  Rightmove  Hammersmith and Fulham       2600      furnished
# 3      126019895  Rightmove  Hammersmith and Fulham       1350      furnished
# 4      127361573  Rightmove  Hammersmith and Fulham       1750      furnished
# ...          ...        ...                     ...        ...            ...
# 9720   124925873  Rightmove               Islington       2817  partFurnished
# 9721    84868017  Rightmove               Islington       5750  partFurnished
# 9722    79835193  Rightmove               Islington       3792  partFurnished
# 9723    65417791  Rightmove               Islington       1582  partFurnished
# 9724   127368341  Rightmove               Islington       1647  partFurnished
#
#      scraping_date
# 0       2022-09-23
# 1       2022-09-23
# 2       2022-09-23
# 3       2022-09-23
# 4       2022-09-23
# ...            ...
# 9720    2022-09-23
# 9721    2022-09-23
# 9722    2022-09-23
# 9723    2022-09-23
# 9724    2022-09-23
#
# [9725 rows x 6 columns]

# %%
# import the data frame to DBeaver

# call the schema created for this project
schema = 'capstone_jmrs'
# get the function to connect to the database
engine = get_engine()

# give the table a unique name
table_name = 'rightmove_1'

# import the table to sql
if engine!=None:
    try:
        rm.to_sql(name=table_name,
                        con=engine,
                        if_exists='replace',
                        schema=schema, 
                        index=False,
                        chunksize=5000, 
                        method='multi')
        print(f"The {table_name} table was imported successfully.")
    
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        engine = None
# Out:
# The rightmove_1 table was imported successfully.
